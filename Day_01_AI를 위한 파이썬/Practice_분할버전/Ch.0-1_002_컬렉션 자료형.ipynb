# %% [markdown]
# <font color='red'><b>**WARNING**</b></font> <br/>
# 어떠한 사유로도 임의로 복사, 촬영, 녹음, 복제, 보관, 전송하거나 허가 받지 않은 저장매체를 이용한 보관, 제3자에게 누설, 공개 또는 사용하는 등의 무단 사용 및 불법 배포 시 법적 조치를 받을 수 있습니다. <br/>
#
# <div style="text-align: right; color: #7f8c8d; font-size: 0.9em; margin-top: 20px;">
# 📝 Author: 박사홍 (Sahong Pak)</br>
# 📧 Contact: sahong.pak@gmail.com</br>
# 📌 Version: v2.0</br>
# 📅 Last Updated: 2026-03-12</br>
# </div>

# %% [markdown]
# </br>

# %% [markdown]
# # 학습 내용
# >이번 장에서는 <strong>Python 컬렉션 자료형(Collection Data Types)</strong>에 대해 학습합니다.</br></br>
# >리스트, 튜플, 집합, 딕셔너리의 특성과 메서드를 학습해봅시다.

# %% [markdown]
# </br>

# %% [markdown]
# # 컬렉션 자료형 (Collection Types)
# > Python의 컬렉션은 <mark style="background-color:#FFF9C4; padding:2px 6px; border-radius:4px;">여러 데이터를 하나의 변수에 저장</mark>하는 자료형입니다.

# %% [markdown]
# >학생 30명의 점수를 저장한다고 가정해봅시다. 단일 변수만 사용하면 `score1`, `score2`, ... `score30`처럼 30개의 변수가 필요합니다.</br>
# >컬렉션을 사용하면 `scores = [85, 90, 78, ...]` 한 줄로 해결됩니다.</br>
# >어떤 컬렉션을 선택하느냐에 따라 코드의 효율과 안전성이 달라집니다.
#
# >각 컬렉션에는 적합한 사용 시나리오가 있습니다. <mark style="background-color:#FFF9C4; padding:2px 6px; border-radius:4px;">list</mark>는 순서가 있고 변경이 필요한 데이터에, <mark style="background-color:#FFF9C4; padding:2px 6px; border-radius:4px;">tuple</mark>은 변경되어선 안 되는 데이터에, <mark style="background-color:#FFF9C4; padding:2px 6px; border-radius:4px;">set</mark>은 중복 제거나 집합 연산이 필요할 때, <mark style="background-color:#FFF9C4; padding:2px 6px; border-radius:4px;">dict</mark>는 이름으로 데이터를 찾아야 할 때 사용합니다.</br>
# >자료구조 선택은 단순한 문법 문제가 아니라 <mark style="background-color:#FFF9C4; padding:2px 6px; border-radius:4px;">성능과 코드 의도를 표현하는 설계 결정</mark>입니다.

# %% [markdown]
# <table style="width:100%">
#   <thead>
#     <tr>
#       <th style="text-align:center">자료형</th>
#       <th style="text-align:center">순서</th>
#       <th style="text-align:center">변경</th>
#       <th style="text-align:center">중복</th>
#       <th>예시</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr><td style="text-align:center"><code>list</code></td><td style="text-align:center">O</td><td style="text-align:center">O</td><td style="text-align:center">O</td><td><code>[1, 2, 3]</code></td></tr>
#     <tr><td style="text-align:center"><code>tuple</code></td><td style="text-align:center">O</td><td style="text-align:center">X</td><td style="text-align:center">O</td><td><code>(1, 2, 3)</code></td></tr>
#     <tr><td style="text-align:center"><code>set</code></td><td style="text-align:center">X</td><td style="text-align:center">O</td><td style="text-align:center">X</td><td><code>{1, 2, 3}</code></td></tr>
#     <tr><td style="text-align:center"><code>dict</code></td><td style="text-align:center">O*</td><td style="text-align:center">O</td><td style="text-align:center">키 X</td><td><code>{"a": 1}</code></td></tr>
#   </tbody>
# </table>

# %% [markdown]
# 💡dict의 순서
# > Python 3.7+부터 딕셔너리는 삽입 순서를 보장합니다.

# %% [markdown]
# </br>

# %% [markdown]
# ## 리스트 (List)
# > <mark style="background-color:#FFF9C4; padding:2px 6px; border-radius:4px;">가변(Mutable)</mark> 순서형 자료구조로, 가장 많이 사용되는 컬렉션입니다.

# %% [markdown]
# ## 리스트 (List)
# > <mark style="background-color:#FFF9C4; padding:2px 6px; border-radius:4px;">가변(Mutable)</mark> 순서형 자료구조로, 가장 많이 사용되는 컬렉션입니다.

# %% [markdown]
# <table style="width:100%">
#   <thead>
#     <tr>
#       <th style="text-align:center">메서드</th>
#       <th>설명</th>
#       <th>예시</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr><td style="text-align:center"><code>append(x)</code></td><td>끝에 요소 추가</td><td><code>lst.append(4)</code></td></tr>
#     <tr><td style="text-align:center"><code>insert(i, x)</code></td><td>i번째에 삽입</td><td><code>lst.insert(0, "a")</code></td></tr>
#     <tr><td style="text-align:center"><code>remove(x)</code></td><td>값으로 삭제</td><td><code>lst.remove(3)</code></td></tr>
#     <tr><td style="text-align:center"><code>pop(i)</code></td><td>i번째 제거 후 반환</td><td><code>lst.pop(0)</code></td></tr>
#     <tr><td style="text-align:center"><code>sort()</code></td><td>정렬 (제자리)</td><td><code>lst.sort()</code></td></tr>
#     <tr><td style="text-align:center"><code>reverse()</code></td><td>역순 (제자리)</td><td><code>lst.reverse()</code></td></tr>
#     <tr><td style="text-align:center"><code>index(x)</code></td><td>값의 인덱스 반환</td><td><code>lst.index("a")</code></td></tr>
#   </tbody>
# </table>

# %%
# TODO 1: fruits에 1, 2, "apple", True 를 저장하고 출력해봅시다.
fruits = [1, 2, "apple", True]
fruits
# Out:
# [1, 2, 'apple', True]

# %%
# TODO 2: fruits에 "banana"를 추가하고 출력해봅시다.
fruits.append("banana")
fruits
# Out:
# [1, 2, 'apple', True, 'banana']

# %%
# TODO 3: fruits의 첫 번째 요소를 출력해봅시다.
fruits[0]
# Out:
# 1

# %%
# TODO 4: fruits의 길이를 출력해봅시다.
len(fruits)
# Out:
# 5

# %%
# TODO 5: fruits에 "cherry", "grape"를 추가하고 출력해봅시다.
# fruits[5:] = ["cherry","grape"]
fruits.extend(["cherry","grape"])
# fruits.append(["cherry","grape"]) #이건 리스트 자체를 주가해서 2차원 리스트가 만들어짐
fruits
# Out:
# [1, 2, 'apple', True, 'banana', 'cherry', 'grape']

# %%
# TODO 6: fruits의 얕은 복사본을 fruits_copy에 저장하고, fruits_copy에 "mango"를 추가한 뒤 fruits와 fruits_copy를 각각 출력해봅시다.
fruits_copy = fruits
fruits_copy.append("mango")
print(fruits)
print(fruits_copy)
# Out:
# [1, 2, 'apple', True, 'banana', 'cherry', 'grape', 'mango']
# [1, 2, 'apple', True, 'banana', 'cherry', 'grape', 'mango']

# %%
# TODO 7. fruits의 첫 번째 요소와 fruits_copy의 첫 번째 요소가 같은 객체 확인해봅시다.
fruits[0]==fruits_copy[0]
# Out:
# True

# %% [markdown]
# </br>

# %% [markdown]
# ### 인덱싱과 슬라이싱 (Indexing & Slicing)

# %%
# TODO 8: numbers에 10, 20, 30, 40, 50을 저장하고, 1번 인덱스부터 2번 인덱스의 슬라이싱 결과를 출력해봅시다.
numbers = [10, 20, 30, 40, 50]
type(numbers)
# numbers[시작 인덱스:끝 인덱스:간격]
# 끝 인덱스 전까지 슬라이싱
print(numbers[1:3])
# Out:
# [20, 30]

# %%
# TODO 9: numbers를 역순으로 출력해봅시다.
# reverse()는 원본을 뒤집어버리는 메서드
numbers.reverse()
numbers[::-1]
print(numbers)
# print(numbers[::-1]) 이것도 가능? 원본에 영향X
# Out:
# [50, 40, 30, 20, 10]
# [10, 20, 30, 40, 50]

# %%
# TODO 10: numbers의 짝수 인덱스 요소를 출력해봅시다.
numbers[::2]
# Out:
# [50, 30, 10]

# %% [markdown]
# </br>

# %% [markdown]
# ### 리스트 컴프리헨션 (List Comprehension)
# > <mark style="background-color:#FFF9C4; padding:2px 6px; border-radius:4px;">간결한 반복 표현</mark>으로 리스트를 생성하는 문법입니다.

# %%
# TODO 11: 리스트 컴프리헨션으로 1부터 4의 제곱을 squares에 저장하고 출력해봅시다.
# squares = [for x in range(1, 5)]
# print(squares) # 이렇게는 오류가 남
# 리스트 컴프리헨션
squares = [x**2 for x in range(1, 5)]
print(squares)

# 기존 방법
squares2 = []
for i in range (1,5):
    squares2.append(i**2)
print(squares2)
# Out:
# [1, 4, 9, 16]
# [1, 4, 9, 16]

# %%
# TODO 12: 리스트 컴프리헨션으로 1부터 9까지 수 중에서 '짝수'를 evens에 저장하고 출력해봅시다.
evens = [x for x in range(1,10) if x % 2 == 0] # 조건 추가도 가능
print(evens)
# Out:
# [2, 4, 6, 8]

# %% [markdown]
# </br>

# %% [markdown]
# ## 튜플 (Tuple)
# > <mark style="background-color:#FFF9C4; padding:2px 6px; border-radius:4px;">불변(Immutable)</mark> 순서형 자료구조로, 생성 후 수정할 수 없습니다.

# %%
# TODO 13: point에 (3, 4) 튜플을 저장하고, x와 y로 언패킹하여 f-string으로 출력해봅시다.
point = (3, 4)
x, y = point
print(x, y) # ,를 기준으로 print하면 공백을 추가하여 출력
print(f"{x},{y}") # f-string으로 출력하기
# Out:
# 3 4
# 3,4

# %%
# TODO 14: try-except를 사용하여 point의 0번 인덱스에 10을 대입 시 발생하는 TypeError를 확인해봅시다.
point[0] = 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 # TODO 14: try-except를 사용하여 point의 0번 인덱스에 10을 대입 시 발생하는 TypeError를 확인해봅시다.
# ----> 2 point[0] = 10
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# 💡튜플 사용 시점
# > 변경되면 안 되는 데이터(좌표, 설정값 등)에 사용합니다.</br>
# > 딕셔너리의 키로 사용할 수 있습니다. (리스트는 불가)

# %% [markdown]
# </br>

# %% [markdown]
# ## 집합 (Set)
# > <mark style="background-color:#FFF9C4; padding:2px 6px; border-radius:4px;">중복을 허용하지 않는</mark> 비순서형 자료구조입니다.

# %%
# TODO 15: set_a에 1, 2, 3, 4 집합을, set_b에 3, 4, 5, 6 집합을 생성하고 f-string으로 출력해봅시다.
# set_a = set(1, 2, 3, 4) 이건 안된다?
set_a = {1, 2, 3, 4}
print(type(set_a))
set_b = {3, 4, 5, 6}
print(f"{set_a}, {set_b}")
# Out:
# <class 'set'>
# {1, 2, 3, 4}, {3, 4, 5, 6}

# %%
# TODO 16: 합집합, 교집합, 차집합 연산자를 사용하여 set_a와 set_b의 집합 연산 결과를 출력해봅시다.
# 원본에 영향을 주지 않음. 따로 이용하려면 변수에 저장하기
print(set_a | set_b)
print(set_a & set_b)
print(set_a - set_b)
# Out:
# {1, 2, 3, 4, 5, 6}
# {3, 4}
# {1, 2}

# %%
# TODO 17: number_list 원소의 중복을 제거한 후 리스트로 변환하여 unique 변수에 저장하고 출력해봅시다.
number_list = [1,2,3,4,55,5,5,5,5]
set(number_list)
unique = list(set(number_list))
unique
# number_list -> set으로 처리하고 -> list() -> unique 변수에 저장한다.
# Out:
# [1, 2, 3, 4, 5, 55]

# %% [markdown]
# </br>

# %% [markdown]
# ## 딕셔너리 (Dictionary)
# > <mark style="background-color:#FFF9C4; padding:2px 6px; border-radius:4px;">키-값(Key-Value) 쌍</mark>으로 데이터를 저장하는 매핑형 자료구조입니다.

# %%
# TODO 18: student에 name은 김철수, age는 20, grade는 A인 딕셔너리를 저장하고 출력해봅시다.
student = {
    "name" : "김철수",
    "age" : 20,
    "grade" : "A+"
}
student
# Out:
# {'name': '김철수', 'age': 20, 'grade': 'A+'}

# %%
# TODO 19: student에 "major" 키로 "CS" 값을 추가하고 출력해봅시다.
student['major'] = "CS"
# student.put("major2","비전공") 이건 안됨
print(student)
# Out:
# {'name': '김철수', 'age': 20, 'grade': 'A+', 'major': 'CS'}

# %%
# TODO 20: students의 Key와 Values를 각각 출력해봅시다.
print(student.keys())
print(student.values())
print(student.items())
# Out:
# dict_keys(['name', 'age', 'grade', 'major'])
# dict_values(['김철수', 20, 'A+', 'CS'])
# dict_items([('name', '김철수'), ('age', 20), ('grade', 'A+'), ('major', 'CS')])

# %%
# TODO 21: student에서 name을 조회하여 값이 있다면 그 값을 없다면 "" (빈값)을, phone을 조회하여 값이 있다면 그 값을 없다면 "없음"을 출력해봅시다.
print(student.get("name"))
print(student.get("name1","없음"))
# Out:
# 김철수
# 없음

# %% [markdown]
# 💡list vs dict 조회 성능
# > 리스트의 `in` 검색은 O(n)이지만, 딕셔너리의 키 검색은 <mark style="background-color:#FFF9C4; padding:2px 6px; border-radius:4px;">O(1)</mark>입니다.</br>
# > 대량 데이터 검색 시 딕셔너리가 훨씬 효율적입니다.

# %% [markdown]
# ### 딕셔너리 추가 메서드 및 컴프리헨션
# > 딕셔너리 <mark style="background-color:#FFF9C4; padding:2px 6px; border-radius:4px;">병합과 간결한 생성</mark>을 위한 문법입니다.

# %%
# TODO 22: base에 name은 "철수", age는 20을, extra에 city는 "서울", grade는 "A"를 저장하고, base에 extra를 병합한 뒤 출력해봅시다.
base = {"name":"철수"}
extra = {"city":"서울", "grade":"A"}
print(base)
base.update(extra)
print(base)
# Out:
# {'name': '철수'}
# {'name': '철수', 'city': '서울', 'grade': 'A'}

# %%
# TODO 23: 딕셔너리 컴프리헨션으로 1부터 5까지 각 숫자를 키, 그 제곱을 값으로 하는 squares를 만들고 출력해봅시다.
squares = {x : x**2 for x in range(1,6) }
print(squares)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
# TODO 24: 딕셔너리 컴프리헨션으로 1부터 5까지 수 중 짝수만 키, 그 제곱을 값으로 하는 even_squares를 만들고 출력해봅시다.
squares2 = {x : x**2 for x in range(1,6) if x % 2 == 0 }
print(squares2)
# Out:
# {2: 4, 4: 16}

# %% [markdown]
# 💡update() vs 직접 할당
# > `update()`는 여러 키를 한 번에 추가/수정할 때 유용합니다.</br>
# > Python 3.9+에서는 `dict1 | dict2` 연산자로 딕셔너리를 병합할 수 있습니다.
