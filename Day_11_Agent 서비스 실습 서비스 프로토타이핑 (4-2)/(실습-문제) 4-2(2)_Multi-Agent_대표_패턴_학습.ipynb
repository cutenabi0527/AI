# %% [markdown]
# # Multi-Agent 대표 패턴 학습 실습
#
# ---
#
# ## 학습 개요
#
# ### 학습 주제
# - **Multi-Agent 시스템의 필요성**: 단일 Agent의 한계를 이해하고 Multi-Agent가 필요한 상황을 판단
# - **Multi-Agent 대표 패턴**: Planner-Worker, Reflection 등 협업 패턴의 구조와 특징 학습
# - **LangGraph 워크플로우 구성**: StateGraph를 활용한 에이전트 간 상태 공유 및 흐름 제어
#
# ### 학습 목표
# - Multi-Agent 시스템의 구조를 이해하고, 상황에 적합한 패턴을 선택하여 구현할 수 있다
#   - 단일 Agent의 한계를 설명하고 Multi-Agent가 필요한 상황을 판단할 수 있다
#   - Planner-Worker 역할 분리 구조를 이해하고 구현할 수 있다
#   - Reflection 패턴과 성과 평가를 통해 결과 품질을 향상시키고 정량적으로 확인할 수 있다
#   - LangGraph StateGraph를 사용하여 Agent 간 상태 공유 워크플로우를 구성할 수 있다
#   - Multi-Agent 대표 패턴 5가지의 특징과 적합한 상황을 비교 설명할 수 있다
#
# ### 핵심 개념
# - **Multi-Agent 시스템**: 여러 Agent가 역할을 분담하여 협업하는 구조. 각 Agent는 독립적인 LLM 호출과 프롬프트를 가지며, State를 통해 정보를 공유한다. 단일 Agent 대비 복잡한 작업에서 품질과 신뢰성이 향상된다.
# - **Planner Agent**: 사용자 요청을 분석하고 작업 계획을 수립하는 역할. "무엇을 해야 하는지"를 정의하며, 직접 실행하지 않고 계획만 수립한다. 계획의 명확성이 전체 결과 품질을 좌우한다.
# - **Worker Agent**: Planner의 계획에 따라 실제 작업을 수행하는 역할. 계획의 각 단계를 구체적인 결과물로 변환한다. 전문화된 프롬프트로 각 단계에 집중한다.
# - **Reflection 패턴**: 결과를 자기 검토하여 품질을 향상시키는 루프. Agent가 생성한 결과를 다시 평가하고 누락/오류를 보완한다. 원본 요청 충족 여부를 체계적으로 검토한다.
# - **StateGraph**: LangGraph에서 제공하는 상태 기반 워크플로우 정의 클래스. 노드(Agent)와 엣지(흐름)로 구성되며, State 객체를 통해 Agent 간 정보를 전달한다. TypedDict를 상속하여 State 스키마를 정의한다.
# - **성과 평가 (Reward Model)**: Multi-Agent 결과 품질을 정량적으로 측정하는 평가 함수. Planner 계획의 완성도, Worker 실행의 충실도, 전체 요청 충족도를 평가한다.
#
# ### 선행 지식
# - Python 함수 정의, 클래스 기본 문법, 딕셔너리 조작 (`dict.get()`, `**dict` 언패킹)
# - 4-2(1) 실습 완료 (ReAct Agent 구현 경험, Tool 사용 이해)
# - LLM API 호출 방식 (`llm.invoke()`), 프롬프트 엔지니어링 기초
# - LangChain 기본 사용법 (ChatOpenAI, 메시지 포맷)

# %% [markdown]
# ---
#
# ## 실습 구성
#
# ### 학습 방향
#
# - **실습 구성 방식**
#   - 문제와 정답 코드가 병렬로 제공되며, 각 단계별 TODO 영역을 채우며 학습자가 직접 구현
#
# - **Required Package**
#   - `langchain>=0.3.0`: LLM 체인 프레임워크
#   - `langchain-openai>=0.2.0`: OpenAI 모델 연동
#   - `langchain-upstage>=0.3.0`: Solar 모델 연동 (대안)
#   - `langgraph>=0.2.0`: Multi-Agent 워크플로우
#   - `python-dotenv>=1.0.0`: 환경 변수 관리
#
# - **실행 환경**
#   - Python 3.10 이상 권장 (LangGraph의 타입 힌팅 기능 활용)
#
# - **Step 요약**
#   - **Step 1 (5분)**: 환경 설정 — 패키지 설치, API 키 설정
#   - **Step 2 (10분)**: 단일 Agent의 한계 체감 — 복잡한 작업을 단일 Agent로 시도
#   - **Step 3 (5분)**: Multi-Agent 패턴 개요 — 5가지 대표 패턴 학습
#   - **Step 4 (15분)**: Planner-Worker 구현 — 계획 수립과 실행 분리
#   - **Step 5 (15분)**: Reflection 패턴 추가 — 자기 검토 루프로 품질 향상
#   - **Step 6 (10분)**: 성과 평가 — 결과 품질을 정량적으로 측정
#
# ### 문제 설명
#
# - **문제 개요**: 이 실습은 Multi-Agent 시스템의 필요성을 이해하고, Planner-Worker 및 Reflection 패턴을 구현하기 위해 설계되었습니다. 학습자는 LangGraph StateGraph를 사용하여 에이전트 간 상태 공유 워크플로우를 구성하고, 최종적으로 Multi-Agent 대표 패턴 5가지의 특징과 적합한 상황을 비교 설명할 수 있어야 합니다.
# - **요구사항 요약**
#   - TODO 1: 단일 Agent로 복잡한 작업을 시도하여 한계 체감
#   - TODO 2: Planner Node를 구현하여 단계별 계획 수립
#   - TODO 3: Worker Node를 구현하여 계획을 실행
#   - TODO 4: Reflection Node를 구현하여 결과 검토 및 개선
#   - TODO 5: 성과 평가 함수를 구현하여 결과 품질 정량 측정
# - **주의사항**
#   - LLM API 키가 올바르게 설정되어야 합니다
#   - 각 Agent의 프롬프트는 역할을 명확히 분리해야 합니다

# %% [markdown]
# ---
#
# # Step 1: 환경 설정
#
# ### Setup: 라이브러리 설치 및 API Key 설정

# %%
# %%capture
# 필요한 패키지 설치
# %pip install "langchain>=0.3.0" "langchain-openai>=0.2.0" "langchain-upstage>=0.3.0" "langgraph>=0.2.0" "python-dotenv>=1.0.0" -q

# %%
import os
import warnings
from dotenv import load_dotenv

warnings.filterwarnings("ignore")

# .env 파일에서 환경변수 로드
load_dotenv()

# API 키 확인 (.env 미설정 시 직접 입력)
if not os.environ.get("OPENAI_API_KEY"):
    os.environ["OPENAI_API_KEY"] = input("🔑 OPENAI_API_KEY를 입력하세요: ")

if not os.environ.get("UPSTAGE_API_KEY"):
    os.environ["UPSTAGE_API_KEY"] = input("🔑 UPSTAGE_API_KEY를 입력하세요: ")
print("✅ 환경 설정 완료")
# Out:
# 🔑 OPENAI_API_KEY를 입력하세요:  ㅁ
# ✅ 환경 설정 완료

# %%
from langchain_openai import ChatOpenAI

# ═══════════════════════════════════════════════════════════════
# 모델 초기화 — OpenAI / Solar 중 택 1 (주석 해제하여 전환)
# ═══════════════════════════════════════════════════════════════

# ── Option A: OpenAI (기본) ──
# llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

# ── Option B: Solar 대안 (주석 해제하여 사용) ──
from langchain_upstage import ChatUpstage
llm = ChatUpstage(model="solar-pro3")

# %%
# 모델 연결 테스트
response = llm.invoke("3일 서울 여행 계획을 간단히 요약해줘.")
print("LLM 응답:")
print(response.content[:200] + "...")
print(f"\n✅ 모델 연결 확인 완료 ({llm.model_name})")
# Out:
# LLM 응답:
# **서울 3일 여행 요약 (예시)**
#
# | Day | 주요 일정 | 비고 |
# |-----|-----------|------|
# | **1일차** | • 오전: 김포공항 → 인사동 (전통 찻집·전통문화 체험) <br>• 점심: 전통 한식 (한옥 레스토랑) <br>• 오후: 경복궁·청와대 (무료 입장) <br>• 저녁: 삼청동 카페거리 산책 후 한식 저녁 |...
#
# ✅ 모델 연결 확인 완료 (solar-pro3)

# %% [markdown]
# ---
#
# # Step 2: 단일 Agent의 한계 체감
#
# ### Concept Check: 단일 Agent의 특징과 한계
#
# **왜 이 단계가 필요한가요?**
# Multi-Agent의 필요성을 이해하려면 먼저 단일 Agent의 한계를 직접 체감해야 합니다. 이론적인 설명보다 실제로 복잡한 작업을 단일 Agent에게 맡겨보고 결과의 문제점을 확인하는 것이 효과적입니다.
#
# **단일 Agent**는 하나의 LLM이 모든 작업을 처리합니다:
# - 장점: 구현이 간단함
# - 단점: 복잡한 작업에서 혼란 발생, 작업 누락, 품질 저하
#
# 복잡한 작업 예시:
# > "3일 서울 여행 계획을 세워줘. 맛집, 관광지, 예산도 포함해서."
#
# 이 작업은 여러 하위 작업을 포함합니다:
# 1. 여행 일정 계획
# 2. 맛집 추천
# 3. 관광지 추천
# 4. 예산 계산
#
# #### 단일 Agent의 한계 시각화
#
# ```
# ┌─────────────────────────────────────────────────────────┐
# │                    단일 Agent                            │
# │  ┌─────────────────────────────────────────────────┐   │
# │  │ 복잡한 요청                                       │   │
# │  │ "3일 서울 여행 + 맛집 + 관광지 + 예산"            │   │
# │  └─────────────────────────────────────────────────┘   │
# │                         ↓                               │
# │  ┌─────────────────────────────────────────────────┐   │
# │  │ 하나의 LLM이 모든 작업을 한 번에 처리             │   │
# │  │ - 일정 계획 + 맛집 + 관광지 + 예산 동시 처리      │   │
# │  └─────────────────────────────────────────────────┘   │
# │                         ↓                               │
# │  ┌─────────────────────────────────────────────────┐   │
# │  │ ⚠️ 발생 가능한 문제                               │   │
# │  │ • 일부 요청 누락 (예: 예산 계산 생략)             │   │
# │  │ • 정보 깊이 부족 (예: 맛집 가격대 누락)           │   │
# │  │ • 일관성 문제 (예: 동선이 비효율적)               │   │
# │  └─────────────────────────────────────────────────┘   │
# └─────────────────────────────────────────────────────────┘
# ```
#
# 단일 Agent가 이 모든 작업을 한 번에 처리하면 어떻게 될까요?

# %% [markdown]
# ### TODO 1: 단일 Agent로 복잡한 작업 시도
#
# - **요구사항**: 단일 Agent에게 복잡한 여행 계획 작업을 요청하고 결과를 확인합니다.
# - **입력**:
#   - `complex_request` (str): 복잡한 여행 계획 요청 문자열
# - **출력**:
#   - `response` (AIMessage): LLM의 응답 객체, `response.content`로 텍스트 접근
# - **예상 결과**: 여행 계획이 출력되지만, 일부 정보 누락 또는 체계성 부족 가능
# - **확인 방법**: `print(response.content)`로 출력 후 요청 사항 충족 여부 체크
# - **힌트**: `llm.invoke()` 메서드를 사용합니다.

# %%
# TODO: 단일 Agent로 복잡한 작업 시도

# 복잡한 작업 요청
complex_request = """
3일 서울 여행 계획을 세워줘.
- 각 날짜별 상세 일정
- 점심, 저녁 맛집 추천 (위치, 메뉴, 가격대)
- 관광지 추천 (입장료, 소요시간)
- 전체 예산 계산
"""

# TODO: llm.invoke()를 사용하여 단일 Agent로 처리하세요
response = llm.invoke(complex_request)

if response is not None:
    print("=== 단일 Agent 응답 ===")
    print(response.content)
else:
    print("=== 코드를 완성해주세요 ===")
# Out:
# === 단일 Agent 응답 ===
# 아래는 **2026년 3월 30일(금) – 4월 1일(일)** 3일간 서울을 알차게 즐길 수 있는 여행 플랜입니다.
# 각 날짜별 일정, 점심·저녁 맛집 정보(위치·추천 메뉴·가격대), 주요 관광지(입장료·예상 소요시간)와 전체 예상 경비를 간단히 정리했습니다.
#
# ---
#
# ## 📅 전체 개요
#
# | 항목 | 금액 (원) | 비고 |
# |------|-----------|------|
# | 항공·교통 | 20,000 | 공항 버스(서울역) → 김포공항 왕복 (1인당) |
# | 호텔 (2박) | 200,000 | 3성급 비즈니스 호텔 (1인 기준) |
# | 식사 (아침·점심·저녁) | 120,000 | 3일 × 3식 × 10,000원 평균 |
# | 교통비 (지하철·도보) | 15,000 | 교통카드 충전 (4일) |
# | 입장료·체험 | 45,000 | 주요 관광지 입장료 |
# | 기타·기념품·팁 | 20,000 | 비상용 |
# | **총합** | **≈ 395,000** | 1인 기준 (가족·연인·친구 2~3명일 경우 인원수로 나눠 계산) |
#
# > **예산 팁**
# - **교통카드**: 선불 충전(50,000원)으로 4일 내내 무제한 사용 가능.
# - **점심·저녁**: 가성비 좋은 체인·현지 식당 위주로 선정했으며, 저녁은 분위기 좋은 레스토랑 1곳씩 포함했습니다.
# - **입장료**: 대부분은 1인당 기준이며, 단체 할인(2명 이상)시 10~20% 절감 가능.
#
# ---
#
# ## 🌞 1일차 (금요일) – 인사동·종로·광화문 일대
#
# ### 08:00 – 09:00 | 아침
# - **카페 “길리” (인사동)**
#   - 위치: 인사동 12길 1, 지하철 3호선 안국역 2번 출구에서 도보 3분
#   - 메뉴: 전통 차 (유자·홍삼) + 토스트 세트
#   - 가격: 8,000원 (1인) → 2인 16,000원
#
# ### 09:30 – 11:30 | 관광 ① | **경복궁**
# - 입장료: 3,000원 (성인)
# - 소요시간: 1.5 시간 (가이드 투어 포함)
# - 팁: 한복 체험(1시간) → 사진 촬영 추천 (추가 5,000원)
#
# ### 12:00 – 13:30 | 점심
# - **“마루” (중식)**
#   - 위치: 종로구 통일로 39, 지하철 종로3가역 1번 출구에서 도보 5분
#   - 메뉴: 짜장면, 짬뽕, 탕수육 (2인 세트)
#   - 가격: 1인당 12,000원 → 24,000원
#
# ### 14:00 – 16:30 | 관광 ② | **북촌 한옥마을**
# - 입장료: 무료 (가이드 투어는 1인당 5,000원)
# - 소요시간: 2 시간 (산책 + 전통 공예 체험)
# - 팁: 전통 차 한잔(5,000원) 포함
#
# ### 17:00 – 18:30 | 저녁
# - **“청진각” (한식)**
#   - 위치: 종로구 청진동 26-5, 지하철 종각역 5번 출구에서 도보 2분
#   - 메뉴: 불고기 백반, 김치전, 된장찌개
#   - 가격: 1인당 13,000원 → 26,000원
#
# ### 19:00 – 20:30 | 자유시간
# - **광화문 광장·세종대왕 동상** – 저녁 산책, 라이트업 감상
# - **근처 편의점** – 간단한 음료·간식 구매
#
# ---
#
# ## 🌞 2일차 (토요일) – 강남·홍대·한강
#
# ### 07:30 – 08:30 | 아침
# - **“이디야 커피 (강남점)”**
#   - 위치: 강남구 테헤란로 123, 지하철 강남역 1번 출구에서 도보 3분
#   - 메뉴: 아메리카노 + 베이글
#   - 가격: 5,500원 (1인) → 2인 11,000원
#
# ### 09:00 – 12:00 | 관광 ① | **코엑스·전시관**
# - 입장료: 무료 (전시·박람회 입장료는 별도)
# - 소요시간: 3 시간 (쇼핑·전시 관람)
# - 팁: 코엑스몰 내 “삼성디지털플라자” 체험 코너 (무료)
#
# ### 12:30 – 13:30 | 점심
# - **“피자알볼로” (강남점)**
#   - 위치: 강남구 강남대로 221, 지하철 강남역 2번 출구에서 도보 4분
#   - 메뉴: 마르게리타, 스파이시 페퍼로니 (2인 세트)
#   - 가격: 1인당 13,000원 → 26,000원
#
# ### 14:00 – 16:00 | 관광 ② | **롯데월드타워 & 스카이데크**
# - 입장료: 27,000원 (스카이데크 + 전망대)
# - 소요시간: 1.5 시간 (전망 관람)
# - 팁: 2층 레스토랑 ‘스카이31’에서 간단한 디저트(5,000원) 추천
#
# ### 16:30 – 18:00 | 자유시간
# - **강남 거리 쇼핑** – 압구정 로데오거리, 강남역 지하상가
# - **카페 “매머드커피”** – 아이스크림 라떼 (5,000원)
#
# ### 18:30 – 20:00 | 저녁
# - **“홍대 야시장” (홍대·마포)**
#   - 위치: 마포구 월드컵로 240, 지하철 홍대입구역 1번 출구에서 도보 5분
#   - 메뉴: 김치전, 떡볶이, 삼겹살 꼬치, 맥주/소주 (1잔)
#   - 가격: 1인당 12,000원 → 24,000원 (2인)
#   - 팁: 2~3곳 골라 먹는 “푸드 마켓” 분위기
#
# ### 20:30 – 22:00 | 문화 체험
# - **홍대 “프리즘” 공연** (밴드·DJ) – 티켓 1인당 15,000원 → 30,000원 (2인)
#
# ---
#
# ## 🌞 3일차 (일요일) – 남산·명동·동대문
#
# ### 08:00 – 09:00 | 아침
# - **“명동 스타벅스”**
#   - 위치: 중구 명동길 3, 지하철 명동역 6번 출구에서 도보 2분
#   - 메뉴: 베이컨 에그 머핀 + 아메리카노
#   - 가격: 7,000원 (1인) → 14,000원
#
# ### 09:30 – 11:30 | 관광 ① | **남산 서울타워**
# - 입장료: 12,000원 (성인) – 스카이데크 포함
# - 소요시간: 1.5 시간 (타워·전망대)
# - 팁: 남산 케이블카 왕복 5,000원 (선택)
#
# ### 12:00 – 13:30 | 점심
# - **“명동교자”**
#   - 위치: 중구 명동 2가 22-1, 지하철 명동역 2번 출구에서 도보 3분
#   - 메뉴: 짜장면, 짬뽕, 군만두 (2인 세트)
#   - 가격: 1인당 11,000원 → 22,000원
#
# ### 14:00 – 16:30 | 관광 ② | **동대문디자인플라자(DDP)·동대문시장**
# - 입장료: DDP 전시회(무료/유료) – 평균 5,000원
# - 소요시간: 2 시간 (전시·쇼핑)
# - 팁: 동대문 야간시장(밤 10시 이후)도 가볍게 둘러볼 수 있음
#
# ### 17:00 – 18:30 | 저녁
# - **“신당동 닭한마리”**
#   - 위치: 성동구 왕십리로 1, 지하철 왕십리역 4번 출구에서 도보 5분
#   - 메뉴: 닭 한 마리(전골), 김치, 반찬 (2인)
#   - 가격: 1인당 12,000원 → 24,000원
#
# ### 19:00 – 20:30 | 자유시간
# - **명동 쇼핑** – 파라다이스, 롯데백화점 등
# - **명동 “카페 파스쿠찌”** – 디저트 + 커피 (5,000원)
#
# ### 21:00 – 22:00 | 귀가·마무리
# - **공항 버스** → 김포공항 → 집 (또는 숙소)
#
# ---
#
# ## 🗺️ 지도 요약 (구글 지도에서 ‘서울 3일 여행’ 검색 시 참고)
#
# | 날짜 | 주요 지역 | 주요 장소 |
# |------|-----------|-----------|
# | 1일차 | 인사동·종로 | 경복궁, 북촌 한옥마을, 청진각 |
# | 2일차 | 강남·홍대 | 코엑스, 롯데월드타워, 홍대 야시장, 프리즘 공연 |
# | 3일차 | 남산·명동·동대문 | 남산서울타워, DDP·동대문시장, 신당동 닭한마리 |
#
# > **Tip**: 구글 지도 “My Map”에 위 장소들을 미리 저장해두면 이동 시 경로 탐색이 편리합니다.
#
# ---
#
# ## 📌 기타 팁
#
# | 항목 | 내용 |
# |------|------|
# | **날씨** | 3월 말~4월 초는 평균 8~15°C, 일교차가 크므로 얇은 외투·코트 권장 |
# | **언어** | 대부분 관광지·가게에서는 영어 표지판·메뉴가 있지만, 간단한 한글 인사(‘안녕하세요’)를 하면 현지인 친절도가 up! |
# | **와이파이** | KT·LG·SKT 로밍 혹은 포켓 와이파이(하루 2,000원~3,000원) 사용 권장 |
# | **교통카드** | T‑money 카드(20,000원 충전) → 지하철·버스·택시 모두 사용 가능 (택시 기본요금 3,800원) |
# | **비상 연락** | 119(응급), 112(경찰), 120(관광 안내) |
# | **현금** | 작은 가게·시장에서는 현금(10,000원 이하) 사용 시 거스름돈을 빠르게 받을 수 있음 |
#
# ---
#
# ### 🎉 마무리
#
# 이 플랜은 **관광·식도락·문화 체험**을 골고루 섞어, 3일 동안 서울의 대표적인 매력을 경험하도록 구성했습니다.
# 예산이 초과될 경우, 점심·저녁을 **편의점 도시락·외식 대신** 셀프 조리(숙소 근처 마트 식재료 구매)로 조절하거나, **입장료를 사전 예약**해 할인받는 방법을 활용해 보세요.
#
# 즐거운 서울 여행 되시길 바랍니다! 🚀✨

# %% [markdown]
# ### Test: 단일 Agent의 한계 확인
#
# 위 결과를 확인해보세요:
# - [ ] 모든 요청 사항이 포함되었나요? (일정, 맛집, 관광지, 예산)
# - [ ] 정보가 체계적으로 정리되었나요? (날짜별, 카테고리별)
# - [ ] 예산 계산이 정확한가요? (숙박+식비+교통+입장료 합계)
# - [ ] 맛집과 관광지 정보가 구체적인가요? (위치, 가격, 소요시간)
#
# **확인 기준**:
# - 4가지 요청 사항 중 1개 이상 누락 → 단일 Agent 한계 체감
# - 정보 간 연결성 부족 (예: 동선 고려 없는 일정) → 체계성 문제 확인
#
# **예상 출력 예시** (한계가 드러나는 경우):
# ```
# ✓ 일정: "Day 1: 경복궁, 명동..." (있음)
# ✓ 관광지: "경복궁, 북촌한옥마을..." (있음)
# △ 맛집: "광장시장 빈대떡" (가격대 누락)
# ✗ 예산: 전체 합계 없음 또는 부정확
# ✗ 동선: 강남→종로→잠실 (비효율적 이동)
# ```
#
# **체감 포인트**: "하나의 Agent가 모든 걸 하려니 복잡하고, 일부 정보가 누락되거나 품질이 일정하지 않네"

# %% [markdown]
# ---
#
# # Step 3: Multi-Agent 패턴 개요
#
# ### Concept Check: Multi-Agent 시스템이란?
#
# **왜 이 단계가 필요한가요?**
# Step 2에서 단일 Agent의 한계를 체감했으니, 이제 그 해결책인 Multi-Agent 시스템의 다양한 패턴을 학습합니다. 어떤 상황에 어떤 패턴이 적합한지 이해해야 실제 프로젝트에서 올바른 선택을 할 수 있습니다.
#
# **Multi-Agent 시스템**은 여러 Agent가 역할을 나누어 협업하는 구조입니다.
#
# #### Single Agent vs Multi-Agent
#
# | 구분 | Single Agent | Multi-Agent |
# |------|--------------|-------------|
# | 구조 | 하나의 LLM이 모든 작업 처리 | 여러 LLM이 역할 분담 |
# | 장점 | 구현 간단 | 복잡한 작업 처리 가능, 품질 향상 |
# | 단점 | 복잡한 작업에서 한계 | 구현 복잡도 증가 |
# | 적합한 상황 | 단순한 Q&A | 다단계 작업, 전문 영역 분리 필요 시 |
#
# #### Multi-Agent 대표 패턴 5가지
#
# | 패턴 | 설명 | 적합한 상황 | 난이도 |
# |------|------|-------------|--------|
# | **Planner-Worker** | 계획 수립 → 실행 분리 | 순차적 다단계 작업 | 하 |
# | **Supervisor** | 관리자가 여러 Worker 조율 | 병렬 처리 필요한 독립 작업 | 중 |
# | **Debate/Discussion** | 여러 Agent가 토론 후 결론 | 다양한 관점이 필요한 의사결정 | 중 |
# | **Reflection** | 자기 검토/개선 루프 | 품질 보장이 중요한 작업 | 하 |
# | **Hierarchical** | 계층적 위임 구조 | 대규모 복잡한 프로젝트 | 상 |
#
# 이번 실습에서는 **Planner-Worker**와 **Reflection** 패턴을 구현합니다.
#
# #### LangGraph란?
#
# **LangGraph**는 LangChain 팀이 개발한 워크플로우 오케스트레이션 라이브러리입니다:
# - **StateGraph**: 상태 기반 그래프로 에이전트 흐름 정의. `TypedDict`를 상속하여 State 스키마 정의
# - **Node**: 각 에이전트가 수행하는 작업 단위. `def node_func(state) -> state` 형태의 함수
# - **Edge**: 노드 간 연결 (흐름 정의). `add_edge("node_a", "node_b")`로 순차 연결
# - **State**: 에이전트 간 공유되는 상태 정보. 딕셔너리 형태로 전달되며 각 노드가 업데이트
#
# #### LangGraph State 흐름도
#
# ```
# ┌──────────────────────────────────────────────────────────────────┐
# │                     LangGraph State 흐름                          │
# ├──────────────────────────────────────────────────────────────────┤
# │                                                                   │
# │  [State 객체]                                                     │
# │  ┌─────────────────────────────────────────────┐                 │
# │  │ user_request: "3일 서울 여행..."             │                 │
# │  │ plan: ""                                     │                 │
# │  │ result: ""                                   │                 │
# │  └─────────────────────────────────────────────┘                 │
# │           │                                                       │
# │           ▼                                                       │
# │  ┌─────────────────┐                                             │
# │  │  Planner Node   │ ─── State 읽기: user_request                │
# │  │  (계획 수립)     │ ─── State 쓰기: plan = "Step 1..."         │
# │  └─────────────────┘                                             │
# │           │                                                       │
# │           ▼ (Edge: planner → worker)                             │
# │  ┌─────────────────┐                                             │
# │  │  Worker Node    │ ─── State 읽기: user_request, plan          │
# │  │  (실행)         │ ─── State 쓰기: result = "Day 1: ..."       │
# │  └─────────────────┘                                             │
# │           │                                                       │
# │           ▼                                                       │
# │  [최종 State]                                                     │
# │  ┌─────────────────────────────────────────────┐                 │
# │  │ user_request: "3일 서울 여행..."             │                 │
# │  │ plan: "Step 1: 일정...\nStep 2: 맛집..."    │ ← Planner 결과  │
# │  │ result: "Day 1: 경복궁(09:00)..."           │ ← Worker 결과   │
# │  └─────────────────────────────────────────────┘                 │
# │                                                                   │
# └──────────────────────────────────────────────────────────────────┘
# ```

# %% [markdown]
# ### Guided Build: LangGraph State 및 기본 구조
#
# LangGraph를 사용하려면 먼저 **State(상태)**를 정의해야 합니다.
# State는 에이전트들이 공유하는 정보를 담는 컨테이너입니다.

# %%
# LangGraph import 및 State 정의
from langgraph.graph import StateGraph, END
from typing import TypedDict, List

class AgentState(TypedDict):
    """Multi-Agent 시스템의 상태 정의"""
    user_request: str     # 사용자 요청
    plan: str             # Planner가 생성한 계획
    result: str           # Worker가 생성한 결과
    reflection: str       # Reflection Agent의 검토 결과
    final_result: str     # 최종 결과
    reflection_count: int # Reflection 반복 횟수 (무한 루프 방지)
    messages: List[dict]  # 에이전트 간 메시지 기록

# State 구조 확인
print("AgentState 필드:")
print("  - user_request: 사용자 요청 문자열")
print("  - plan: Planner Agent의 계획")
print("  - result: Worker Agent의 실행 결과")
print("  - reflection: Reflection Agent의 검토 결과")
print("  - final_result: 최종 결과")
print("  - reflection_count: Reflection 반복 횟수 (무한 루프 방지)")
print("  - messages: 에이전트 간 메시지 기록")
# Out:
# AgentState 필드:
#   - user_request: 사용자 요청 문자열
#   - plan: Planner Agent의 계획
#   - result: Worker Agent의 실행 결과
#   - reflection: Reflection Agent의 검토 결과
#   - final_result: 최종 결과
#   - reflection_count: Reflection 반복 횟수 (무한 루프 방지)
#   - messages: 에이전트 간 메시지 기록

# %% [markdown]
# ---
#
# # Step 4: LangGraph로 Planner-Worker 구현
#
# ### Concept Check: 역할별 프롬프트 설계
#
# **왜 이 단계가 필요한가요?**
# 이제 Multi-Agent 패턴 중 가장 기본적인 Planner-Worker를 직접 구현합니다. "계획"과 "실행"을 분리함으로써 각 Agent가 자신의 역할에 집중할 수 있고, 결과의 체계성이 향상됩니다.
#
# 각 Agent는 고유한 역할과 프롬프트를 가집니다:
#
# - **Planner**: 요청을 분석하고 단계별 계획을 수립. "무엇을", "어떤 순서로" 할지 정의
# - **Worker**: 계획을 받아 각 단계를 실행. 구체적인 정보와 결과물 생성
#
# LangGraph에서는 각 Agent를 **노드(Node)**로 정의하고, State를 통해 정보를 전달합니다.
#
# #### Agent 간 메시지 흐름 예시
# ```
# [User] "3일 서울 여행 계획"
#     ↓
# [Planner] State 읽기: user_request
#     ↓ LLM 호출
# [Planner] State 쓰기: plan = "Step 1: 일정 계획\nStep 2: 맛집 추천..."
#     ↓
# [Worker] State 읽기: user_request, plan
#     ↓ LLM 호출
# [Worker] State 쓰기: result = "Day 1: 경복궁(09:00-12:00)..."
# ```

# %% [markdown]
# ### TODO 2: Planner Node 구현
#
# - **요구사항**: 사용자 요청을 분석하고 단계별 계획을 수립하는 Planner Node를 구현합니다.
# - **입력**:
#   - `state` (AgentState): 현재 상태 딕셔너리
#     - `state["user_request"]` (str): "3일 서울 여행 계획..." 형태의 요청
# - **출력**:
#   - `AgentState`: 업데이트된 상태 딕셔너리
#     - `plan` (str): "Step 1: 일정 계획\nStep 2: 맛집 추천..." 형태의 계획
#     - `messages` (List[dict]): 메시지 로그에 Planner 결과 추가
# - **예상 결과**: 3~5개의 Step으로 구성된 계획 문자열
# - **확인 방법**: `print(result_state['plan'])`으로 계획 출력 확인
# - **힌트**: State를 받아서 업데이트된 State를 반환하는 함수로 구현합니다. `{**state, "plan": plan}`으로 State 업데이트

# %%
# TODO: Planner Node 구현

def planner_node(state: AgentState) -> AgentState:
    """
    Planner Node: 사용자 요청을 분석하고 단계별 계획을 수립합니다.
    
    Args:
        state: 현재 AgentState
    
    Returns:
        업데이트된 AgentState (plan 필드 추가)
    """
    user_request = state["user_request"]
    
    # TODO: Planner 프롬프트를 작성하세요
    # - 사용자 요청을 분석하고 단계별 계획을 수립하도록 지시
    # - "계획만 수립하고, 직접 실행하지 말 것"을 명시
    # - 출력 형식: Step 1: [작업], Step 2: [작업], ...
    planner_prompt = f"""
    당신은 작업 계획을 수립하는 플래너 에이전트입니다.

    user_request를 분석하여, 수행할 작업을 단계별로 나열하세요.
    각 단계는 구체적이고 실행 가능성이 있어야 합니다.
    반드시 [계획만 수립]하고, 직접 [실행하지 마세요].

    사용자 요청: {user_request} 

    출력 양식:
    Step 1: [작업],
    Step 2: [작업],
    ...
    """
    
    # LLM 호출
    response = llm.invoke(planner_prompt)
    plan = response.content
    
    # 메시지 기록 추가
    messages = state.get("messages", [])
    messages.append({
        "sender": "Planner",
        "receiver": "Worker",
        "content": plan,
        "task_type": "plan"
    })
    
    # TODO: State 업데이트하여 반환
    return {
        **state,
        "plan": plan,  # TODO: plan 변수로 교체
        "messages": messages
    }

# 테스트
test_state = {
    "user_request": "3일 서울 여행 계획을 세워줘. 맛집, 관광지, 예산 포함.",
    "plan": "",
    "result": "",
    "messages": []
}

# TODO 완료 후 테스트
result_state = planner_node(test_state)
if result_state['plan'] is not None:
    print("=== Planner Node 결과 ===")
    print(f"계획:\n{result_state['plan']}")
else:
    print("=== 코드를 완성해주세요 ===")
# Out:
# === Planner Node 결과 ===
# 계획:
# Step 1: 사용자 요청 분석 및 핵심 요구사항 정의
# Step 2: 3일 동안 방문할 서울 관광지와 맛집 후보 리스트 작성
# Step 3: 각 관광지 및 맛집의 운영 시간·입장료·위치 정보 수집
# Step 4: 일정별 동선 최적화 및 시간대별 배치 계획 수립
# Step 5: 일일 예상 총비용(교통·식사·입장료) 계산
# Step 6: 예산 범위 내에서 세부 비용 조정 및 대안 제시
# Step 7: 최종 3일 일정표(일자, 시간, 장소, 활동, 예산) 작성
# Step 8: 최종 계획 검토 및 피드백 반영 여부 확인

# %% [markdown]
# ### TODO 3: Worker Node 구현
#
# - **요구사항**: Planner의 계획을 받아 각 단계를 실행하는 Worker Node를 구현합니다.
# - **입력**:
#   - `state` (AgentState): 현재 상태 딕셔너리
#     - `state["plan"]` (str): Planner가 생성한 계획
#     - `state["user_request"]` (str): 원본 사용자 요청
# - **출력**:
#   - `AgentState`: 업데이트된 상태 딕셔너리
#     - `result` (str): 계획의 각 단계를 실행한 구체적인 결과
#     - `messages` (List[dict]): 메시지 로그에 Worker 결과 추가
# - **예상 결과**: 각 Step에 대한 구체적인 정보가 포함된 결과물 (날짜별 일정, 맛집 목록 등)
# - **확인 방법**: `print(final_state['result'][:500])`으로 결과 일부 확인
# - **힌트**: State에서 plan을 읽어 실행하고 result를 업데이트합니다.

# %%
# TODO: Worker Node 구현

def worker_node(state: AgentState) -> AgentState:
    """
    Worker Node: Planner의 계획을 받아 각 단계를 실행합니다.
    
    Args:
        state: 현재 AgentState (plan 포함)
    
    Returns:
        업데이트된 AgentState (result 필드 추가)
    """
    plan = state["plan"]
    user_request = state["user_request"]
    
    # TODO: Worker 프롬프트를 작성하세요
    # - Planner의 계획을 받아 각 단계를 실행하도록 지시
    # - 각 단계별 구체적인 정보를 포함하도록 요청
    worker_prompt = f"""
    당신은 계획을 실행하는 worker Agent 입니다.

    Planner가 세운 계획을 받아 각 단계별로 실행하고 결과를 제공하세요.
    [각 단계별로 구체적인 정보를 포함]해 주세요.

    --------------------------------------
    사용자 요청: {user_request}
    실행 계획: {plan}
    --------------------------------------
    계획을 단계별로 실행하고, 단계별 결과를 자세히 작성하세요.
    """
    
    # LLM 호출
    response = llm.invoke(worker_prompt)
    result = response.content

    # 메시지 기록 추가
    messages = state.get("messages", [])
    messages.append({
        "sender": "Worker",
        "receiver": "User",
        "content": result,
        "task_type": "result"
    })
    
    # TODO: State 업데이트하여 반환
    return {
        **state,
        "result": result,  # TODO: result 변수로 교체
        "messages": messages
    }

# TODO 완료 후 테스트
final_state = worker_node(result_state)
if final_state['result'] is not None:
    print("=== Worker Node 결과 ===")
    print(f"실행 결과:\n{final_state['result'][:500]}...")
else:
    print("=== 코드를 완성해주세요 ===")
# Out:
# === Worker Node 결과 ===
# 실행 결과:
# We need to act as a worker agent executing the plan. Provide step-by-step execution with concrete info. We need to respond in Korean presumably. The user wants a 3-day Seoul travel plan with attractions, restaurants, budget.
#
# The system prompt says we are a worker Agent executing plan. We have to execute each step and provide results. So we need to produce step-by-step results: analysis, list of attractions & restaurants, gather operating hours, entrance fees, location, optimize itinerary, compu...

# %% [markdown]
# ### Guided Build: LangGraph 워크플로우 구성
#
# 이제 Planner Node와 Worker Node를 **StateGraph**로 연결하여 워크플로우를 구성합니다.

# %%
from langgraph.graph import StateGraph, START, END

# LangGraph 워크플로우 정의 (Guided Build - 코드 제공)
workflow = StateGraph(AgentState)

# 노드 추가
workflow.add_node("planner", planner_node)
workflow.add_node("worker", worker_node)

# 엣지 연결: planner → worker → END
workflow.add_edge(START, "planner")
workflow.add_edge("planner", "worker")
workflow.add_edge("worker", END)

# 컴파일
app = workflow.compile()

print("LangGraph 워크플로우 구성 완료!")
print("흐름: planner → worker → END")
# Out:
# LangGraph 워크플로우 구성 완료!
# 흐름: planner → worker → END

# %% [markdown]
# ### Test: LangGraph Multi-Agent 실행
#
# 컴파일된 워크플로우를 실행하여 Planner → Worker 협업을 테스트합니다.
#
# **확인 기준**:
# - [ ] Planner가 3~5개의 명확한 Step을 생성했는가?
# - [ ] Worker가 각 Step을 구체적인 정보로 실행했는가?
# - [ ] State를 통해 plan이 Worker에게 전달되었는가?
# - [ ] 단일 Agent 결과 대비 체계성이 향상되었는가?
#
# **Agent 간 메시지 흐름 확인**:
# ```python
# # messages 리스트에서 흐름 확인
# for msg in result["messages"]:
#     print(f"[{msg['sender']}] → [{msg['receiver']}]: {msg['task_type']}")
# # 예상 출력:
# # [Planner] → [Worker]: plan
# # [Worker] → [User]: result
# ```
#
# **체감 포인트**: "LangGraph로 계획과 실행을 분리하니 워크플로우가 명확하고 결과 품질도 높아졌네!"

# %%
# LangGraph 워크플로우 실행
def run_multi_agent(user_request: str) -> dict:
    """
    LangGraph Multi-Agent 시스템 실행
    
    Args:
        user_request: 사용자 요청
    
    Returns:
        최종 상태를 담은 딕셔너리
    """
    print("🚀 LangGraph Multi-Agent 시스템 시작\n")
    
    # 초기 상태 설정
    initial_state = {
        "user_request": user_request
    }
    
    # 워크플로우 실행
    print("📋 [Planner Agent] 계획 수립 중...")
    print("⚙️ [Worker Agent] 계획 실행 중...")
    
    final_state = app.invoke(initial_state)
    
    print("✅ 실행 완료\n")
    
    return final_state

# 테스트 실행
workflow_result = run_multi_agent("서울 2박3일 여행 계획 + 예산 50만원 이내")

print("=" * 50)
print("📊 최종 결과")
print("=" * 50)
print(workflow_result["result"])
# Out:
# 🚀 LangGraph Multi-Agent 시스템 시작
#
# 📋 [Planner Agent] 계획 수립 중...
# ⚙️ [Worker Agent] 계획 실행 중...
# ✅ 실행 완료
#
# ==================================================
# 📊 최종 결과
# ==================================================
# **Worker Agent – 2박 3일 서울 여행 (예산 500,000원 이내) 실행 보고서**
# **작성일:** 2026‑03‑30
# **진행자:** Solar Pro 3 (Upstage AI)
#
# ---
#
# ## Step 1 : 제약 조건 및 여행 목적 확인
# | 항목 | 내용 |
# |------|------|
# | **여행 기간** | 2박 3일 (도착 1일차, 전일 관광 2일차, 마지막 관광 3일차) |
# | **예산** | 총 500,000원 이하 (교통·숙박·식사·관광·기타 포함) |
# | **여행 목적** | - 주요 관광지 탐방 (문화·역사·현대) <br> - 가벼운 쇼핑 (기념품·패션) <br> - 휴식·카페·산책 (일정 중 여유시간 확보) |
# | **특이 요구사항** | - 대중교통 이용 선호 (지하철·버스) <br> - 2박 모두 도심(동대문·명동·홍대 등) 근처 숙소를 원함 <br> - 식사는 한식당·편의점·뷔페 등 가성비 높은 옵션 위주 |
#
# **결과** – 제약 조건을 명확히 파악하고, 여행 목적이 관광·쇼핑·휴식임을 확인했습니다. 다음 단계에서는 예산을 세부 항목으로 배분합니다.
#
# ---
#
# ## Step 2 : 예산 500,000원을 항목별 배분
# | 항목 | 배분 금액 | 비고 |
# |------|----------|------|
# | **교통** (왕복 이동·대중교통) | 120,000원 | KTX·무궁화·고속버스 등 + 3일 동안 지하철·버스 패스 |
# | **숙박** (2박) | 180,000원 | 1박당 약 90,000원 → 게스트하우스·에어비앤비 기준 |
# | **식사** (3끼/일) | 120,000원 | 1끼당 약 13,333원 → 편의점·카페·저렴한 한식 |
# | **관광·입장료** | 40,000원 | 주요 명소 4~5곳 + 체험 1~2곳 |
# | **기타 비용** | 40,000원 | 통신비·비상금·기념품·간식·택시 등 |
# | **예비·조정** | 0원 | 전체 합계가 500,000원에 정확히 맞음 |
#
# **결과** – 500,000원 안에서 각 항목별 예산을 설정하고, 전체 비용이 정확히 목표에 부합함을 확인했습니다.
#
# ---
#
# ## Step 3 : 2박 가능한 숙소 검색 및 필터링
# **검색 엔진:** 네이버·다음·Airbnb·Booking.com (2026‑03‑30 기준 최신 가격)
# **필터링 조건**
# - 2박 (체크인·체크아웃 연속 가능)
# - 500,000원 이하 전체 요금 (세금·청소비 포함)
# - 위치: 종로구·동대문구·용산구·마포구와 같은 도심 접근성이 좋은 구역
# - 평점 ★4 이상, 청결·보안·와이파이 확인
# - 객실 타입: 더블룸·트윈룸 (1인실·2인실 모두 가능)
#
# **검색 결과 (상위 5개)**
#
# | 숙소명 | 위치 | 2박 요금(원) | 객실 타입 | 평점 | 주요 특징 | 비고 |
# |--------|------|--------------|-----------|------|----------|------|
# | **서울 게스트하우스 ‘동대문’** | 종로구 (동대문역사문화공원 인근) | 170,000 | 2인 더블룸 | ★4.4 | 무료 와이파이, 세탁실, 조식 제공 | 가장 저렴한 옵션 |
# | **에어비앤비 ‘홍대 라마다’** | 마포구 (홍대입구역 5분) | 185,000 | 2인 트윈룸 | ★4.7 | 주방 이용 가능, 주차 가능 (유료) | 자유로운 조리 가능 |
# | **‘이비스 앰배서더 명동’** | 중구 (명동역 바로 앞) | 195,000 | 2인 더블룸 | ★4.2 | 24시간 프론트, 무료 조식 | 쇼핑·맛집 접근성 최고 |
# | **‘코스텔러 호텔’** | 용산구 (한강공원 인근) | 200,000 | 2인 더블룸 | ★4.3 | 루프탑 바, 무료 피트니스 | 한강 전망과 여유 |
# | **‘스타이 호텔 강남’** | 강남구 (강남역 도보 8분) | 210,000 | 2인 더블룸 | ★4.1 | 비즈니스 라운지, 무료 와이파이 | 교통은 다소 멀지만 시설이 우수 |
#
# **선택** → **서울 게스트하우스 ‘동대문’** (가격 저렴, 홍대·명동·시청 모두 지하철 1~2정거장, 조식 제공)
#
# **예약 확정**
# - 체크인: 2026‑12‑20 (1일차)
# - 체크아웃: 2026‑12‑22 (3일차)
# - 예약 번호: **GHS-20261220-001**
# - 결제: 예약 시점에 170,000원 전액 결제 완료
#
# **결과** – 예산(180,000원) 내에 2박 숙소를 성공적으로 확보했습니다.
#
# ---
#
# ## Step 4 : 서울에서 출발·도착 교통 수단 비교 및 선택
# | 옵션 | 왕복 비용(원) | 소요 시간(편도) | 주요 장점 | 단점 |
# |------|----------------|----------------|----------|------|
# | **KTX (서울→부산→서울)** | 110,000 (왕복) | 2시간 30분 (서울→부산) / 3시간 (부산→서울) | 빠름, 좌석·와이파이 | 부산 경유 → 불필요 |
# | **무궁화 (서울→대전→서울)** | 85,000 (왕복) | 1시간 40분 (서울→대전) / 2시간 10분 (대전→서울) | 직통, 저렴 | 대전 경유 → 불필요 |
# | **고속버스 (서울→인천)** | 30,000 (왕복) | 1시간 15분 | 저렴, 시내 중심부 직통 | 좌석·와이파이 제한 |
# | **지하철·버스 (서울 시내 이동)** | 30,000 (3일 무제한 패스) | - | 무제한 이용, 24시간 운영 | 패스 구매 필요 |
# | **택시·카셰어** | 50,000 (예상) | - | 편리 | 비용 높음 |
#
# **선택** → **서울에서 출발·도착은 고속버스** (인천·수원·청주 등) → **왕복 30,000원** (예산에 충분히 포함)
# **서울 시내 이동** → **3일 무제한 교통 패스** (지하철·버스) → **30,000원** (교통 항목에 포함)
#
# **결과** – 전체 교통 비용은 60,000원 (고속버스 왕복 + 무제한 패스)으로, 초기 배분 120,000원을 60,000원으로 절감하고 남은 60,000원을 식사·관광에 재배분 가능.
#
# ---
#
# ## Step 5 : 2박 3일 일정 – 관광·체험 선정 및 입장료 확인
# | 날짜 | 시간대 | 관광지·체험 | 입장료(원) | 운영시간 | 비고 |
# |------|--------|------------|-----------|----------|------|
# | **1일차** (2026‑12‑20) | 09:00‑11:30 | **경복궁** (왕실 정원) | 3,000 | 09:00‑18:00 | 한국어 가이드 무료 (시간표 확인) |
# | | 12:00‑13:30 | **인사동 거리** (전통 공예·카페) | 무료 | 09:00‑22:00 | 쇼핑·점심 (편의점 간편식) |
# | | 13:30‑15:30 | **북촌 한옥마을** (산책) | 무료 | 09:00‑18:00 | 사진 촬영 추천 |
# | | 16:00‑18:00 | **홍대 거리** (카페·버스킹) | 무료 | 10:00‑23:00 | 저녁 전 간단한 스낵 |
# | | 18:30‑20:30 | **동대문 야시장** (쇼핑·맛있는 길거리 음식) | 무료 | 18:00‑24:00 | 저녁 식사·기념품 |
# | **2일차** (2026‑12‑21) | 09:00‑11:30 | **N서울타워** (전망·디지털 박물관) | 12,000 | 10:00‑23:00 | 케이블카 왕복 포함 |
# | | 12:00‑13:30 | **남산 둘레길** (산책) | 무료 | 06:00‑22:00 | N서울타워와 연계 |
# | | 13:30‑15:00 | **명동 쇼핑 거리** (패션·화장품) | 무료 | 10:00‑22:00 | 점심 (편의점 김밥·컵라면) |
# | | 15:30‑17:30 | **삼청동 카페 투어** (전통 한옥 카페) | 무료 | 11:00‑20:00 | 휴식·디저트 |
# | | 18:00‑20:00 | **한식당 ‘백리향’** (한식 뷔페) | 15,000 | 11:30‑22:00 | 가성비 높은 점심·저녁 겸용 (전날 남은 식사 활용) |
# | **3일차** (2026‑12‑22) | 08:00‑10:30 | **전쟁기념관** (전시) | 5,000 | 09:00‑18:00 | 마지막 문화 체험 |
# | | 11:00‑13:00 | **서울타워 스카이워크** (전망) | 5,000 (추가) | 10:00‑22:00 | N서울타워 입장 포함 |
# | | 13:30‑15:00 | **코엑스 아쿠아리움** (해양 전시) | 15,000 | 09:30‑20:00 | 아이·가족 체험 (선택) |
# | | 15:30‑17:00 | **여의도 한강공원** (산책·자전거) | 무료 | 05:00‑23:00 | 여유로운 마무리 |
# | | 17:30‑18:30 | **체크아웃 전 마지막 편의점 간식** | 5,000 | - | 남은 예산 활용 (간식) |
#
# **입장료 총액**
# - 경복궁 3,000
# - N서울타워 12,000 + 스카이워크 5,000 = 17,000
# - 전쟁기념관 5,000
# - 코엑스 아쿠아리움 15,000
# - **합계 = 40,000원** (예산에 맞음)
#
# **결과** – 주요 관광지·체험을 선정하고, 입장료를 모두 합산했으며 예산 40,000원에 부합함을 확인했습니다.
#
# ---
#
# ## Step 6 : 이동 동선 최적화 (구역별 하루 일정)
# - **동대문·인사동·북촌** → 한 구역(도심 북서부) → 도보·지하철 1정거장(종로3가)
# - **홍대** → 동쪽(도심 남서부) → 지하철 2호선 홍대입구역, 도보 5분
# - **남산·N서울타워** → 중앙(남산) → 버스·케이블카(20분)
# - **명동·삼청동** → 서쪽(도심 중앙) → 지하철 4호선 명동역, 도보 10분
# - **전쟁기념관·코엑스·여의도** → 동쪽(도심 남동부) → 지하철 2·9호선·버스 연계
#
# **동선 설계**
# - **첫째 날**: 동대문 → 인사동 → 북촌 → 홍대 (구역 이동 최소화, 도보+지하철 1~2정거장)
# - **둘째 날**: N서울타워 → 남산 둘레길 → 명동 → 삼청동 (동선 직선, 지하철 1~2정거장)
# - **셋째 날**: 전쟁기념관 → 코엑스 → 여의도 (대중교통 환승 최소화, 9호선·버스 활용)
#
# **결과** – 구역별 효율적인 동선을 설계했으며, 이동시간을 최소화했습니다.
#
# ---
#
# ## Step 7 : 하루 3끼 식사 예산 설정 및 가성비 식당 목록
# ### 식사 예산 재조정
# - 기존 120,000원 → 교통 절감 60,000원 → **새 식사 예산 = 180,000원** (6,000원/끼)
# - 1일 3끼 × 3일 = 9끼, 평균 6,000원/끼 목표
#
# ### 가성비 식당 리스트
# | 식사 구분 | 식당명 | 위치 | 가격대(원) | 특징 | 비고 |
# |----------|--------|------|-----------|------|------|
# | **아침** | **CU 편의점** | 게스트하우스 1층 | 3,000~4,000 | 간편식·우유·빵 | 언제든지 구매 가능 |
# | | **이디야 커피** | 동대문역 인근 | 4,500~5,000 | 아메리카노·베이글 | 커피와 간단한 베이커리 |
# | | **김밥천국** | 동대문시장 | 5,000~6,000 | 김밥·라면·도시락 | 가성비 최고 |
# | **점심** | **백리향 (한식 뷔페)** | 종로3가 | 12,000~15,000 | 무한리필·다양한 반찬 | 2일차 점심 (예산 초과 시 김밥천국으로 대체) |
# | | **명동길 거리 푸드코트** | 명동역 | 8,000~10,000 | 김치찌개·된장찌개·볶음밥 | 저렴한 한식 |
# | | **홍대 ‘청춘식당’** | 홍대입구역 | 9,000~11,000 | 비빔밥·떡볶이 | 분위기 좋음 |
# | **저녁** | **동대문 야시장 ‘대왕계란말이·떡볶이’** | 동대문 야시장 | 8,000~12,000 | 길거리 음식·맥주 세트 | 저렴·현지 분위기 |
# | | **‘신라면’ 편의점** | 전 구역 | 5,000~7,000 | 컵라면·삼각김밥·즉석밥 | 언제든 구매 가능 |
# | | **‘아날로그 카페’** | 삼청동 | 6,000~8,000 | 아메리카노·케이크 | 디저트·간식 |
#
# **예산 사용 예시**
# - 1일차 저녁: 야시장 12,000원 → 9,000원으로 조정 (간식·음료 포함)
# - 2일차 점심: 백리향 15,000원 → 김밥천국 6,000원 (예산 맞춤)
# - 3일차 아침·점심·저녁: 편의점·푸드코트 혼합, 평균 6,000원/끼 → 총 36,000원
#
# **결과** – 식사 예산을 180,000원으로 재조정하고, 6,000원 수준의 가성비 식당을 선정했습니다.
#
# ---
#
# ## Step 8 : 전체 비용 합산 및 예산 초과 여부 검토
# | 항목 | 금액(원) | 비고 |
# |------|----------|------|
# | **교통** (고속버스 왕복 + 무제한 패스) | 60,000 | 초기 120,000 → 절감 |
# | **숙박** (게스트하우스 2박) | 170,000 | 초기 180,000 → 절감 |
# | **식사** (1일 3끼) | 180,000 | 초기 120,000 → 증액 |
# | **관광·입장료** | 40,000 | 초기 40,000 (변동 없음) |
# | **기타** (통신비·비상금·기념품) | 20,000 | 초기 40,000 → 절감 (기념품 최소화) |
# | **예비·조정** | 0 | - |
# | **총합** | **470,000원** | **예산 500,000원 이하** → **30,000원 절감** |
#
# **조정 사항**
# - 교통·숙박 비용을 절감하고, 식사 예산을 180,000원으로 증액했지만 전체적으로 30,000원 여유가 남음.
# - 남은 예산은 **기념품(핸드크림·마스크팩)** 혹은 **택시 1회** 등에 활용 가능.
#
# **결과** – 전체 비용이 470,000원으로 목표 예산(500,000원) 내에 완전히 들어맞으며, 30,000원의 여유가 남았습니다.
#
# ---
#
# ## Step 9 : 최종 확정된 2박 3일 여행 일정표
# ### 전체 일정 개요
# | 날짜 | 시간대 | 활동 | 이동수단 | 식사 | 숙소 |
# |------|--------|------|----------|------|------|
# | **1일차 (2026‑12‑20)** | 07:30‑09:00 | 고속버스 탑승 (서울→인천) | 고속버스 | - | - |
# | | 09:30‑11:30 | 경복궁 관람 | 도보/지하철 1정거장 (종로3가) | 편의점 김밥·우유 | - |
# | | 12:00‑13:30 | 인사동 거리 산책·카페 | 도보 | 김밥천국 김밥·라면 | - |
# | | 14:00‑15:30 | 북촌 한옥마을 | 도보 | - | - |
# | | 16:00‑18:00 | 홍대 카페·버스킹 | 지하철 2호선 (홍대입구역) → 도보 | 이디야 커피·베이글 | - |
# | | 18:30‑20:30 | 동대문 야시장 쇼핑·저녁 | 도보 | 야시장 대왕계란말이·떡볶이 세트 | 게스트하우스 ‘동대문’ (체크인 19:00) |
# | **2일차 (2026‑12‑21)** | 08:00‑09:30 | 아침 – 편의점 (CU) | 도보 | - | - |
# | | 09:30‑11:30 | N서울타워·스카이워크 | 지하철 4호선 → 버스 20분 (케이블카) | - | - |
# | | 12:00‑13:30 | 남산 둘레길 산책 | 도보·버스 | 편의점 김밥 | - |
# | | 13:30‑15:00 | 명동 쇼핑 거리 | 지하철 4호선 (명동역) 도보 | 명동 푸드코트 김치찌개·볶음밥 | - |
# | | 15:30‑17:00 | 삼청동 카페·한옥 체험 | 지하철 3호선 (안국역) → 도보 | 아날로그 카페 아메리카노·케이크 | - |
# | | 18:00‑20:00 | 저녁 – 백리향 (한식 뷔페) | 도보 | 백리향 15,000원 (예산 맞춤) | 게스트하우스 (체크인) |
# | **3일차 (2026‑12‑22)** | 07:30‑09:00 | 전쟁기념관 관람 | 지하철 1호선 (시청역) → 도보 | - | - |
# | | 09:30‑11:00 | 스카이워크 재방문 (전망) | 도보 | - | - |
# | | 11:30‑13:00 | 코엑스 아쿠아리움 (선택) | 지하철 9호선 → 버스 5분 | 코엑스 푸드코트 김밥·컵라면 | - |
# | | 13:30‑15:00 | 여의도 한강공원 산책·자전거 | 버스 602 | 편의점 간식 | - |
# | | 15:00‑17:00 | 체크아웃 & 짐 정리 | 도보 | 편의점 간식 (남은 예산 활용) | - |
# | | 17:30‑18:30 | 고속버스 탑승 (서울→인천) | 고속버스 | - | - |
# | | 19:00‑20:30 | 인천 → 자택 이동 (고속버스) | 고속버스 | - | - |
#
# ### 비용 상세 내역 (예산 470,000원)
# | 구분 | 금액(원) | 비고 |
# |------|----------|------|
# | 고속버스 왕복 | 30,000 | 인천·서울 구간 |
# | 무제한 교통 패스 (3일) | 30,000 | 지하철·버스 |
# | 게스트하우스 2박 | 170,000 | 조식 포함 |
# | 경복궁 | 3,000 | 입장료 |
# | N서울타워·스카이워크 | 17,000 | 입장료 + 케이블카 |
# | 전쟁기념관 | 5,000 | 입장료 |
# | 코엑스 아쿠아리움 | 15,000 | 입장료 (선택) |
# | 식사 (9끼) | 180,000 | 편의점·푸드코트·야시장 등 |
# | 기타·기념품·비상금 | 20,000 | 마스크·핸드크림 등 |
# | **합계** | **470,000** | **예산 내** |
#
# **남은 여유 30,000원 활용법**
# 1. **기념품**: 마스크팩·핸드크림·전통 차 등 2~3개 구입 (≈ 15,000원)
# 2. **택시**: 필요시 1~2회 택시 이용 (≈ 10,000원)
# 3. **추가 체험**: 작은 디저트 체험(한옥 카페 티타임) (≈ 5,000원)
#
# **결과** – 일정과 비용을 모두 정리했으며, 예산 초과 없이 실행 가능한 최종 계획을 완성했습니다.
#
# ---
#
# ## Step 10 : 여행 전 체크리스트
# | 체크 항목 | 내용 | 비고 |
# |----------|------|------|
# | **여권·티켓** | 고속버스 승차권, KTX 승차권(필요 시) | 모바일 QR코드 저장 |
# | **숙소 예약 확인** | 예약 번호 GHS‑20261220‑001, 체크인 시간 19:00 | 예약 확인 메일·스크린샷 |
# | **교통 패스** | 3일 무제한 교통 패스 구매 영수증 | 현금·카드 결제 가능 |
# | **식사 옵션** | 편의점·푸드코트 영업시간 확인 (구글 지도) | 김밥·컵라면 구매 리스트 |
# | **관광 입장권** | N서울타워·스카이워크, 경복궁, 전쟁기념관 사전 예약 여부 확인 | 현장 구매 가능하지만 온라인 사전 구매 권장 |
# | **비상 연락망** | 호텔 전화번호, 여행사 연락망, 현지 한국 대사관 | 비상 상황 시 활용 |
# | **날씨 예보** | 2026‑12‑20~22 날씨 (서울) – 평균 5~8°C, 눈·비가 올 가능성 낮음 | 겨울 옷·우산 준비 |
# | **현금·카드** | 현금 200,000원, 신용카드 2개, 현지 교통카드(T‑money) 충전 | 대중교통·기념품 구입용 |
# | **배터리·보조배터리** | 스마트폰·노트북 충전, 휴대용 보조배터리 2개 | 이동 중 사용 |
# | **기타** | 마스크·손소독제·여행용 어댑터(멀티플러그) | 코로나·위생 대비 |
# | **기념품 구매 리스트** | 전통 차·마스크팩·핸드크림·소형 전통 부채 | 남은 예산 활용 예정 |
#
# **최종 확인** – 체크리스트를 모두 검토했으며, 모든 서류와 물품을 준비했습니다.
#
# ---
#
# ## 전체 요약
# 1. **예산**: 470,000원 (500,000원 이하) – 30,000원 여유
# 2. **숙소**: 게스트하우스 ‘동대문’ (170,000원, 조식 포함)
# 3. **교통**: 고속버스 왕복 30,000원 + 3일 무제한 교통 패스 30,000원
# 4. **식사**: 9끼 모두 6,000원 이하로 계획, 편의점·푸드코트·야시장 활용
# 5. **관광**: 경복궁, 북촌, 홍대, N서울타워, 전쟁기념관, 코엑스 아쿠아리움 등 6~7곳, 총 입장료 40,000원
# 6. **동선**: 구역별 도보·지하철 최소화, 이동시간 평균 15~20분
# 7. **기타**: 기념품·비상금·택시 활용 가능 예산 30,000원
#
# **이 일정표와 비용 계획을 그대로 실행하시면 2박 3일 동안 500,000원 이내에서 알차고 여유로운 서울 여행을 즐기실 수 있습니다.**
#
# ---
#
# *끝.*

# %% [markdown]
# ---
#
# # Step 5: Reflection 패턴 추가
#
# ### Concept Check: Reflection 패턴이란?
#
# **왜 이 단계가 필요한가요?**
# Planner-Worker만으로도 체계적인 결과를 얻을 수 있지만, 결과의 품질을 한 단계 더 높이려면 자기 검토가 필요합니다. Reflection 패턴은 "결과가 요청을 충족하는가?"를 스스로 평가하고 개선하는 **루프**입니다.
#
# **Reflection 패턴**은 Agent가 자신의 결과를 검토하고 개선하는 자기 검토 루프입니다.
#
# #### Reflection 루프 구조 (핵심)
#
# ```
# [Planner] → [Worker] → [Reflection] ─── 품질 충분? ──→ [END]
#                 ↑                              │
#                 └──── 개선 필요 (재실행) ────────┘
# ```
#
# **핵심 포인트**: Reflection은 단순 평가가 아니라 **평가→개선 루프**입니다.
# - Reflection Agent가 결과를 검토하고 "충족/부분 충족/미충족"을 판정
# - "부분 충족" 또는 "미충족"이면 개선된 결과를 만들어 Worker에게 다시 보냄
# - 무한 루프 방지를 위해 `reflection_count`로 최대 반복 횟수를 제한 (예: 최대 1회)
#
# #### Reflection Agent의 역할
# - 결과가 원본 요청을 충족하는지 검토
# - 누락된 정보나 개선 사항 식별
# - **충족 시**: 최종 결과 확정 → END
# - **미충족 시**: 개선 피드백을 result에 반영 → Worker 재실행
#
# #### Agent 간 메시지 흐름 (Reflection 포함)
# ```
# [Worker] State 쓰기: result = "Day 1: 경복궁..."
#     ↓
# [Reflection] State 읽기: user_request, plan, result
#     ↓ LLM 호출 (검토)
# [Reflection] 판정:
#     충족 → State 쓰기: final_result = result → END
#     부분 충족 → State 쓰기: result = "개선된 결과..." → Worker 재실행
# ```

# %% [markdown]
# ### TODO 4: Reflection Agent 추가
#
# - **요구사항**: Worker의 결과를 검토하고 개선 제안을 하는 Reflection Node를 구현합니다.
# - **입력**:
#   - `state` (AgentState): 현재 상태 딕셔너리
#     - `state["result"]` (str): Worker가 생성한 결과
#     - `state["user_request"]` (str): 원본 사용자 요청
#     - `state["plan"]` (str): Planner가 생성한 계획
# - **출력**:
#   - `AgentState`: 업데이트된 상태 딕셔너리
#     - `reflection` (str): 검토 결과 (충족 여부, 강점, 개선 필요)
#     - `final_result` (str): 개선된 최종 결과
#     - `messages` (List[dict]): 메시지 로그에 Reflection 결과 추가
# - **예상 결과**:
#   - 검토 결과: "충족/부분 충족/미충족" 판정 + 구체적 피드백
#   - 최종 결과: Worker 결과를 보완한 완성도 높은 결과물
# - **확인 방법**: `print(reflection_state['reflection'][:800])`으로 검토 결과 확인
# - **힌트**: 결과를 검토하고 누락된 부분이나 개선점을 제안합니다. 프롬프트에 "검토 항목"과 "출력 형식"을 명시하세요.

# %%
# TODO: Reflection Node 구현

MAX_REFLECTIONS = 1  # 최대 Reflection 반복 횟수 (무한 루프 방지)

def reflection_node(state: AgentState) -> AgentState:
    """
    Reflection Node: Worker의 결과를 검토하고 개선 제안을 합니다.
    
    Args:
        state: 현재 AgentState (result 포함)
    
    Returns:
        업데이트된 AgentState (reflection, final_result 필드 추가)
    """
    result = state["result"]
    user_request = state["user_request"]
    plan = state["plan"]
    
    # TODO: Reflection 프롬프트를 작성하세요
    # - Worker의 결과를 검토하고 원본 요청 충족 여부 평가
    # - 검토 항목: 요구사항 충족, 누락 정보, 정확성, 개선 필요 사항
    # - 출력 형식: ## 검토 결과 + ## 최종 개선 결과
    reflection_prompt = f"""
    당신은 결과를 검토하는 평가 Agent입니다.

    Worker Agent가 생성한 결과를 검토하고, 원본의 요청을 만족하는지 평가하세요.
    --------------------------------------------------
    검토항복
    1. 원본 요청의 요구사항 을 만족하는가?
    2. 누락 정보가 존재하는가?
    3. 응답 결과의 정보가 정확한가?
    4. 개선 필요 사항이 있는가?
    --------------------------------------------------
    원본 요청: {user_request}
    실행 계획: {plan}
    실행 결과: {result}
    --------------------------------------------------
    위 내용을 바탕으로 검토하고 아래와 같은 형식으로 작성하새요.
    ## 검토 결과
    - 충족 여부: [충족/부분 충족/미충족]
    - 강점: [잘된 부분]
    - 약점: [잘못된 부분]
    - 누락 여부: [누락된 부분]
    - 정확성: [정확성]
    - 개선 여부: [개선할 부분]

    ## 최종 개선 결과
    [Worker Agent의 결과를 보완하여 최종 결과 작성]

    
    """
    
    # LLM 호출
    response = llm.invoke(reflection_prompt)
    reflection = response.content

    # 메시지 기록 추가
    messages = state.get("messages", [])
    messages.append({
        "sender": "Reflection",
        "receiver": "User",
        "content": reflection,
        "task_type": "reflection"
    })
    
    # TODO: State 업데이트하여 반환 (reflection_count 증가 포함)
    return {
        **state,
        "reflection": reflection,  # TODO: reflection 변수로 교체
        "final_result": reflection,  # TODO: reflection 변수로 교체
        "reflection_count": state.get("reflection_count", 0) + 1,
        "messages": messages
    }

def should_continue_reflection(state: AgentState) -> str:
    """Reflection 후 종료할지 Worker로 돌아갈지 판단"""
    count = state.get("reflection_count", 0)
    reflection = state.get("reflection", "")
    
    # 최대 반복 횟수 초과 시 종료
    if count >= MAX_REFLECTIONS:
        return "end"
    
    # "충족" 판정이면 종료, 아니면 Worker로 재실행
    if "충족 여부: 충족" in reflection:
        return "end"
    
    return "worker"

# TODO 완료 후 테스트
reflection_state = reflection_node(final_state)
if reflection_state['reflection'] is not None:
    print("=== Reflection Node 결과 ===")
    print(f"검토 결과:\n{reflection_state['reflection'][:800]}...")
else:
    print("=== 코드를 완성해주세요 ===")
# Out:
# === Reflection Node 결과 ===
# 검토 결과:
# ## 검토 결과
#
# | 검토 항목 | 내용 |
# |-----------|------|
# | **충족 여부** | **부분 충족** – 원본 요청(3일 서울 여행 · 맛집, 관광지, 예산 포함)은 전반적으로 반영되었습니다. 다만 구체적인 예산 금액(예: $300 또는 ₩500,000 등)과 교통·식사·입장료 상세 계산이 일부 부족합니다. |
# | **강점** | 1. **요청 분석** → 3일 일정, 맛집·관광객, 예산 포함이라는 핵심 요구사항을 명확히 파악.<br>2. **단계별 실행 계획** → 8개의 실행 단계가 체계적으로 제시되어 흐름을 이해하기 쉬움.<br>3. **다양한 후보 리스트** → 주요 관광지(경복궁, 남산타워, 동대문, 홍대 등)와 맛집(한식당·양식·중식·디저트) 후보를 폭넓게 제시.<br>4. **운영시간·입장료·위치**를 표 형태로 정리, 사용자가 빠르게 확인 가능. |
# | **약점** | 1. **예산 범위가 구체적이지 않음** – “예산 범위 내에서” 라는 문구만 있었고, 실제 금액·환율·예상 총비용을 제시하지 않아 사용자가 적정성을 판단하기 어려움.<br>2. **동선 최적화 설명이 부족** – 같은 구역(예: 종로‑청와대, 강남‑코엑스) 간 이동 거리·시간을 구체적으로 언급하지 않아 실제 일정 수립 시 비효율 가능성 존재.<br>3. **일일 총비용 계산이 누락** – 교통·식사·입장료 항목별 비용을 합산하지 않아 전체 예산을 파악하기 힘듦.<br>4. **예산 조정 대안 제시가 미흡** – 비용이 초과되는 경우 대체 옵션(저가 식당, 무료 전시관 등)을 제시하지 않음.<br>5. ...

# %% [markdown]
# ### TODO 5: 성과 평가 함수 구현
#
# - **요구사항**: Multi-Agent 시스템의 결과를 평가하는 함수를 구현합니다.
# - **입력**:
#   - `state` (AgentState): 현재 상태 딕셔너리 (user_request, plan, result, reflection 포함)
# - **출력**:
#   - `dict`: 평가 결과
#     - `score` (int): 종합 점수 (0~100)
#     - `feedback` (str): 전체 피드백
#     - `details` (dict): 세부 평가 항목별 점수
# - **평가 항목**:
#   - Planner 평가: 계획의 완성도, 단계 적절성 (0~30점)
#   - Worker 평가: 실행 품질, 정보 충실도 (0~40점)
#   - 전체 평가: 사용자 요청 충족도 (0~30점)
# - **예상 결과**:
#   - 종합 점수: 70~90점 범위 (Reflection 적용 후 품질 향상)
#   - JSON 출력 예시:
#     ```json
#     {
#       "planner_score": 25,
#       "worker_score": 35,
#       "overall_score": 25,
#       "feedback": "계획이 체계적이며, 대부분의 요청 사항을 충족함"
#     }
#     ```
# - **확인 방법**: `print(f"종합 점수: {evaluation['score']}/100")`로 점수 출력
# - **힌트**: LLM에게 평가 기준과 State 정보를 제공하여 점수와 피드백을 생성합니다. JSON 파싱 시 `re.search()`로 JSON 부분만 추출합니다.

# %%
# TODO: 성과 평가 함수 구현
# 아래 함수를 완성하세요.

import json
import re

def evaluate_multi_agent(state: AgentState) -> dict:
    """
    Multi-Agent 시스템의 성과를 평가합니다.
    
    Args:
        state: 현재 AgentState (user_request, plan, result, reflection 포함)
    
    Returns:
        dict: {"score": int, "feedback": str, "details": dict}
    """

    # 평가 프롬프트 구성
    eval_prompt = f"""
당신은 Multi-Agent 시스템의 성과를 평가하는 평가자입니다.

## 평가 기준
1. Planner 평가 (0~30점): 계획의 완성도, 단계 구성의 적절성
2. Worker 평가 (0~40점): 실행 품질, 정보의 충실도와 정확성
3. 전체 평가 (0~30점): 사용자 요청 충족도, 협업 효율성

## 입력 정보
- 사용자 요청: {state['user_request']}
- Planner의 계획: {state['plan']}
- Worker의 결과: {state['result']}
- Reflection 검토: {state.get('reflection', '없음')}

## 출력 형식
반드시 아래 JSON 형식만 출력하세요. [다른 텍스트는 포함하지 마세요.]
{{"planner_score": <0~30>, "worker_score": <0~40>, "overall_score": <0~30>, "feedback": "<전체 피드백>"}}
"""

    response = llm.invoke(eval_prompt)
    content = response.content

    # JSON 파싱 (마크다운 코드 블록 처리)
    try:
        # 마크다운 코드 블록에서 JSON 추출 (```json ... ``` 또는 ``` ... ```)
        json_match = re.search(r'```(?:json)?\s*([\s\S]*?)\s*```', content)
        if json_match:
            json_str = json_match.group(1)
        else:
            # 코드 블록이 없으면 중괄호로 시작하는 JSON 추출
            json_match = re.search(r'\{[\s\S]*\}', content)
            json_str = json_match.group(0) if json_match else content

        result = json.loads(json_str)

        # TODO: result를 이용하여 점수를 합산하고 결과를 반영하세요
        total_score = result['planner_score'] + result['worker_score'] + result['overall_score']      # TODO: 세 항목의 점수를 합산하세요

        return {
            "score": total_score,
            "feedback": result['feedback'],   # TODO: result의 feedback 값으로 교체하세요
            "details": {
                "planner": result['planner_score'],    # TODO: result의 planner_score 값으로 교체하세요
                "worker": result['worker_score'],     # TODO: result의 worker_score 값으로 교체하세요
                "overall": result['overall_score']     # TODO: result의 overall_score 값으로 교체하세요
            }
        }
    except Exception as e:
        return {"score": 0, "feedback": f"평가 실패: {str(e)}", "details": {}}

# 테스트
evaluation = evaluate_multi_agent(reflection_state)
if evaluation['feedback'] is not None:
    print("=== 성과 평가 결과 ===")
    print(f"종합 점수: {evaluation['score']}/100")
    print(f"세부 점수: Planner {evaluation['details'].get('planner', 0)}/30, Worker {evaluation['details'].get('worker', 0)}/40, 전체 {evaluation['details'].get('overall', 0)}/30")
    print(f"피드백: {evaluation['feedback']}")
else:
    print("=== 코드를 완성해주세요 ===")
# Out:
# === 성과 평가 결과 ===
# 종합 점수: 90/100
# 세부 점수: Planner 25/30, Worker 35/40, 전체 30/30
# 피드백: 계획은 8단계로 구조화돼 실행이 용이했으나 예산 상한을 명시하지 않아 비용 파악이 어려웠고, 동선 최적화와 시간 배분이 구체화되어 있지 않아 실용성이 떨어졌습니다. 예산 상한(예: ₩500,000)을 명시하고 일일·전체 비용을 KRW·USD 양면으로 제시하면 사용자 만족도와 실행 가능성이 크게 향상될 것입니다.

# %% [markdown]
# ### Guided Build: Reflection 패턴 워크플로우 구성
#
# 이제 Planner → Worker → Reflection 순서로 워크플로우를 구성합니다.
# Reflection은 `should_continue_reflection` 함수로 **조건 분기**합니다:
# - 품질 충분 또는 최대 반복 도달 → END
# - 개선 필요 → Worker로 재실행

# %%
# Reflection 패턴 워크플로우 구성
workflow_reflection = StateGraph(AgentState)

# 노드 추가
workflow_reflection.add_node("planner", planner_node)
workflow_reflection.add_node("worker", worker_node)
workflow_reflection.add_node("reflection", reflection_node)

# 엣지 연결: planner → worker → reflection
workflow_reflection.add_edge(START, "planner")
workflow_reflection.add_edge("planner", "worker")
workflow_reflection.add_edge("worker", "reflection")

# Reflection 후 조건 분기: END 또는 Worker 재실행
workflow_reflection.add_conditional_edges(
    "reflection",
    should_continue_reflection,
    {"end": END, "worker": "worker"}
)

# 컴파일
app_reflection = workflow_reflection.compile()

print("Reflection 패턴 워크플로우 구성 완료!")
print("흐름: planner → worker → reflection → (조건 분기) → END 또는 worker")
# Out:
# Reflection 패턴 워크플로우 구성 완료!
# 흐름: planner → worker → reflection → (조건 분기) → END 또는 worker

# %%
# Reflection 패턴 워크플로우 실행
def run_multi_agent_reflection(user_request: str) -> dict:
    """
    Reflection 패턴이 포함된 Multi-Agent 시스템 실행
    
    Args:
        user_request: 사용자 요청
    
    Returns:
        최종 상태를 담은 딕셔너리
    """
    print("🚀 Reflection Multi-Agent 시스템 시작\n")
    
    # 초기 상태 설정
    initial_state = {
        "user_request": user_request
    }
    
    # 워크플로우 실행
    print("📋 [Planner Agent] 계획 수립 중...")
    print("⚙️ [Worker Agent] 계획 실행 중...")
    print("🔍 [Reflection Agent] 결과 검토 중...")
    
    final_state = app_reflection.invoke(initial_state)
    
    print(f"\n✅ 실행 완료 (Reflection 횟수: {final_state['reflection_count']})\n")
    
    return final_state

# 테스트 실행
reflection_result = run_multi_agent_reflection("서울 2박3일 여행 계획 + 예산 50만원 이내")

print("=" * 50)
print("📊 Reflection 최종 결과")
print("=" * 50)
print(reflection_result["final_result"])
# Out:
# 🚀 Reflection Multi-Agent 시스템 시작
#
# 📋 [Planner Agent] 계획 수립 중...
# ⚙️ [Worker Agent] 계획 실행 중...
# 🔍 [Reflection Agent] 결과 검토 중...
#
# ✅ 실행 완료 (Reflection 횟수: 1)
#
# ==================================================
# 📊 Reflection 최종 결과
# ==================================================
# ## 검토 결과
# - **충족 여부**: **부분 충족**
#   - 전체 흐름·구조는 계획대로 진행됐으며, 2박 3일 일정과 예산 설계가 제시되었습니다.
#   - 그러나 구체적인 일정과 비용·예약 정보가 **일부 누락**되고, **수치·가격 정보가 정확하지 않음**(예: 숙소·교통·식사·입장료 등 실제 평균 가격과 차이가 큼).
#
# - **강점**
#   1. **단계별 프로세스**가 명확히 구분돼 있어 검토·보완이 용이함.
#   2. **예산 항목**(교통·숙박·식사·입장료·기타) 별 배분 아이디어를 제시함.
#   3. **다양한 후보**(숙소·식당·교통 패스·패스 종류)를 제시해 선택 폭을 넓힘.
#
# - **약점**
#   1. **구체적인 후보 가격·예약 링크 부재** → 실제 금액 확인이 어려움.
#   2. **날짜·시간·소요시간**이 구체적이지 않아 일정표가 ‘초안’ 수준에 머무름.
#   3. **예산 합계**가 500 만원(≈ 500 000 KRW) 이하인지 검증하지 않음.
#   4. **대체·비용 절감 방안**이 미흡함(예: 할인 쿠폰·무료 입장·대체 교통 수단 등).
#
# - **누락 여부**
#   - **숙소**와 **교통**에 대한 실제 예약 단계(예약 URL·예약 방법·시뮬레이션된 예약 내역)
#   - **식사·입장료** 등 항목별 구체적인 **예산 예시**(실제 평균 가격)와 **총액** 계산
#   - **예산 검증**(총액 < 500 000 KRW) 및 **초과 시 재조정** 로직
#   - **준비물·현지 팁·안전 정보** 등 여행 전반에 필요한 추가 안내
#
# - **정확성**
#   - 제시된 가격·비용은 실제 시장 평균과 차이가 크며, 일부 항목은 **과소/과대** 평가됨(예: 숙박 45 000 KRW/박은 저가 호스텔 수준이며, 대부분의 관광객은 최소 7 만원 이상 지불함).
#   - 교통 비용(지하철 1일권 6 000 KRW)도 실제 구간·패스에 따라 변동 가능.
#
# - **개선 여부**
#   - **구체적 데이터**(실제 최저가·평균 가격·링크) 추가가 필요.
#   - **예산 검증**을 명시적으로 수행해 총액이 500 000 KRW를 초과하지 않도록 조정.
#   - **예약 시뮬레이션**(예: “OO호텔 1박 80 000 KRW, 총 150 000 KRW” 등)과 **예약 방법**(웹사이트·앱·전화) 제시.
#   - **비용 절감 팁**(서울시 관광패스, 무료 입장 가능한 박물관, 할인 쿠폰, 조기 예약, 대중교통 이용) 포함.
#
# ---
#
# ## 최종 개선 결과
# 아래는 원본 요청을 **전부 만족**하도록 보완·구체화한 최종 여행 계획입니다.
# 모든 금액은 **2026‑04‑01 (목) ~ 2026‑04‑03 (토)** 일정에 맞춰 **500 000 KRW 이하**를 목표로 산정했으며, 실제 예약 가능한 옵션을 예시로 제공하고, 필요 시 비용 절감 방안도 함께 제시합니다.
#
# ---
#
# ### 1️⃣ Day 1 – 목요일 (도착)
# | 시간 | 일정 | 소요시간 | 비고 |
# |------|------|----------|------|
# | 10:00 | 인천국제공항 → **Gimpo Airport** (도착) | – | 비행기 도착 |
# | 10:30 | **AREX** (직통) → **Seoul Station** (KTX) | 43 min | AREX 9 000 KRW |
# | 11:30 | 숙소 체크인 (예산 75 000 KRW/박) | – | **Ibis Ambassador Seoul Myeongdong** (2박) |
# | 12:30 | 점심 – **Myeongdong Kalguksu** (3 인분, 30 000 KRW) | 45 min | *예산: 30 000 KRW* |
# | 14:00 | **경복궁** 입장 (15 000 KRW) → **북촌 한옥마을** 산책 (무료) | 2 h | |
# | 16:30 | **인사동** 카페·전통공예 관람 (무료) | 1 h | |
# | 18:30 | 저녁 – **Mokryeonjeong** (한정식, 4인, 40 000 KRW) | 1 h | |
# | 20:00 | 숙소 복귀 | – | |
# | 21:00 | 자유시간 – **홍대 거리** (간식·맥주) | 1 h | |
#
# ---
#
# ### 2️⃣ Day 2 – 금요일
# | 시간 | 일정 | 소요시간 | 비고 |
# |------|------|----------|------|
# | 08:30 | 아침 – 숙소 조식 (무료) | – | |
# | 09:30 | **N서울타워** (케이블카 1인당 10 000 KRW) | 30 min 왕복 | *예산: 20 000 KRW* |
# | 11:30 | **동대문디자인플라자(DDP)** (무료) → **동대문시장** 구경 (점심) | 2 h | |
# | 13:30 | 점심 – **동대문시장 푸드코트** (1인당 8 000 KRW) | 1 h | *예산: 32 000 KRW* |
# | 15:00 | **롯데월드** (입장권 1인당 45 000 KRW, 할인 쿠폰 적용 30 000 KRW) | 4 h | *예산: 120 000 KRW* |
# | 19:00 | 저녁 – **한강공원 BBQ** (재료·음료 1인당 12 000 KRW) | 2 h | *예산: 48 000 KRW* |
# | 21:00 | 숙소 복귀 | – | |
# | 23:00 | 자유시간 – **숙소 바** (무료 음료) | 2 h | |
#
# ---
#
# ### 3️⃣ Day 3 – 토요일 (출발)
# | 시간 | 일정 | 소요시간 | 비고 |
# |------|------|----------|------|
# | 08:00 | 아침 – 숙소 조식 (무료) | – | |
# | 09:00 | 체크아웃 → **COEX 몰** (무료 입장) | – | |
# | 09:30 | **COEX Aquarium** (입장 1인당 25 000 KRW) | 1 h | *예산: 50 000 KRW* |
# | 11:00 | **삼성동** 카페·쇼핑 | 1 h | |
# | 12:00 | 점심 – **김밥천국** (1인당 7 000 KRW) | 30 min | *예산: 21 000 KRW* |
# | 13:30 | **서울역** → **인천공항** (KTX 1인당 25 000 KRW) | 35 min | |
# | 15:00 | **인천공항** 도착 → 출국 | – | |
# | – | **예산 총 검토** | – | 498 000 KRW (여유 2 000 KRW) |
#
# ---
#
# ## 2️⃣ 예산 상세 배분 (500 000 KRW 이하)
#
# | 항목 | 금액 (KRW) | 비고 |
# |------|------------|------|
# | **교통** | 34 000 | AREX 9 000, KTX 왕복 25 000, 지하철·버스 1일권 6 000 × 2일 |
# | **숙박** | 150 000 | Ibis Ambassador Myeongdong 75 000 KRW / 박 × 2 박 |
# | **식사** | 171 000 | Day1 점심 30 000, 저녁 40 000, Day2 점심 32 000, 저녁 48 000, Day3 점심 21 000 |
# | **입장료·체험** | 155 000 | 경복궁 15 000, N서울타워 20 000, COEX Aquarium 50 000, DDP·롯데월드 등 (할인 쿠폰 적용) |
# | **기타·기념품·팁** | 40 000 | 팁·기념품·음료·간식 등 |
# | **예비·비상비** | 2 000 | 예상치 못한 변동 대비 |
# | **총액** | **498 000** | **500 000 KRW 이하** |
#
# > **※** 위 금액은 2025‑2026년 현재 **실제 평균 가격**을 기반으로 산출했으며, 사전 예약·쿠폰·조기할인 시 5 ~ 10 % 추가 절감 가능.
#
# ---
#
# ## 3️⃣ 교통 수단 확정 & 비교
#
# | 교통 옵션 | 비용 (KRW) | 장점 | 단점 |
# |-----------|-----------|------|------|
# | **AREX + KTX** | 9 000 + 25 000 = 34 000 | 가장 빠른 이동 (인천↔서울) | AREX·KTX 사전 예매 필요 |
# | **공항버스 (Airport Limousine) → 지하철** | 15 000 + 5 000 = 20 000 | 공항버스 정차역 많음 | 소요시간 1 h 이상 |
# | **지하철 1일권 (T‑money)** | 6 000 × 2일 = 12 000 | 무제한 환승, 편리 | 공항↔시내 이동 비용 별도 |
# | **택시(리무진)** | 60 000 | 문앞 서비스 | 비용 과다, 교통체증 위험 |
#
# **선택**: **AREX + KTX** (총 34 000 KRW) → 이동 시간 최소화, 비용 대비 효율 최고.
#
# ---
#
# ## 4️⃣ 숙소 최종 선택 & 예약
#
# | 후보 | 가격 (KRW/박) | 객실 유형 | 위치 | 취소 정책 | 예약 링크 |
# |------|--------------|-----------|------|-----------|-----------|
# | **Ibis Ambassador Seoul Myeongdong** | 75 000 | 트윈/더블 | 명동·홍대 인근, 지하철 4번 출구 도보 2분 | **무료 취소** – 체크인 24 h 전까지 전액 환불 | https://booking.ibis.com/seoul-myeongdong |
# | **Seoul City Hostel (Hongdae)** | 45 000 | 도미터리/프라이빗 룸 | 홍대, 24 h 프론트 | 최소 1일 전 취소 시 전액 환불 | https://www.seoulcityhostel.com |
# | **Myeongdong Guesthouse** | 60 000 | 2인실 | 명동·시청역 | 48 h 전까지 무료 취소 | https://myeongdongguesthouse.kr |
#
# **추천**: **Ibis Ambassador Seoul Myeongdong**
# - **가격**: 75 000 KRW / 박 × 2 박 = **150 000 KRW**
# - **위치**: 주요 관광지(경복궁, 동대문, 명동)와 가까워 이동 시간 최소화
# - **편의**: 무료 와이파이, 조식 제공, 24 h 프론트, **무료 취소** 가능 → 예약 시 ‘환불 정책 확인’ 후 진행
#
# > **예약 시뮬레이션**
# > 1. 위 URL 접속 → ‘Check‑in: 2026‑04‑01’, ‘Check‑out: 2026‑04‑03’ 선택
# > 2. 객실 유형 ‘Classic Room (2 people)’ 선택 → 금액 150 000 KRW 표시
# > 3. ‘Apply Discount Code: SEOUL2026’ (실제 존재하는 할인코드 예시) 적용 → **135 000 KRW** 로 절감
# > 4. ‘Pay by Credit Card’ → 예약 완료 (예약 번호: AB12345678)
#
# (※ 실제 할인코드는 사전 확인이 필요합니다.)
#
# ---
#
# ## 5️⃣ 식사·입장료 상세 후보 & 비용
#
# | 구분 | 후보 1 | 후보 2 | 후보 3 | 평균 비용 (KRW) |
# |------|--------|--------|--------|----------------|
# | **점심 (Day1)** | Myeongdong Kalguksu (3인분) – 30 000 | Jongno Gukje Market (세트) – 28 000 | – | **≈ 29 000** |
# | **저녁 (Day1)** | Mokryeonjeong (한식) – 40 000 | Hangang River BBQ – 38 000 | – | **≈ 39 000** |
# | **점심 (Day2)** | DDP 푸드코트 – 32 000 | Lotte Mart Food Court – 30 000 | – | **≈ 31 000** |
# | **저녁 (Day2)** | 한강 BBQ – 48 000 | 홍대 포장마차 – 45 000 | – | **≈ 46 000** |
# | **점심 (Day3)** | 김밥천국 – 7 000 | COEX 푸드코트 – 8 000 | – | **≈ 7 500** |
# | **입장료** | 경복궁 – 15 000 | N서울타워 – 10 000 (온라인 사전 구매) | COEX Aquarium – 25 000 | **≈ 16 500** |
# | **기타·기념품** | 전통 공예품, 화장품 등 – 30 000 | – | – | **≈ 30 000** |
#
# **예산 검증**:
# - 식사 총합 ≈ 171 000 KRW
# - 입장료 총합 ≈ 155 000 KRW
# - 기타·기념품 ≈ 30 000 KRW
# - **합계** = 456 000 KRW (교통·숙박 제외) → 교통·숙박 포함 시 **498 000 KRW** (예산 안)
#
# ---
#
# ## 6️⃣ 비용 절감 팁
#
# | 영역 | 절감 방법 | 절감 예상액 |
# |------|----------|------------|
# | **교통** | AREX·KTX 조기 예매 (10 % 할인) | –6 000 |
# | | T‑money 카드 초기 충전 대신 **교통카드 쿠폰** 활용 | –2 000 |
# | **숙박** | ‘주말 할인’·‘조기 예약 15 % 할인’ 적용 | –22 500 |
# | **식사** | **점심 2인분 주문** → 1인당 10 % 절감 | –6 000 |
# | | **무료 Wi‑Fi** 이용 → 데이터 비용 절감 | –5 000 |
# | **입장료** | **Seoul City Pass** (48 h) 25 000 KRW (경복궁·N타워·COEX 등 포함) | –30 000 |
# | **기념품** | **시장·편의점**에서 저가 상품 구매 | –10 000 |
# | **총 절감 예상** |  | **≈ 73 500 KRW** → 최종 예산 **≈ 424 500 KRW** (여유 75 500 KRW) |
#
# ---
#
# ## 7️⃣ 최종 여행 계획 문서 (요약)
#
# ```
# === 서울 2박 3일 여행 계획 (2026‑04‑01 ~ 2026‑04‑03) ===
# - 예산: 500,000 KRW (≤ 500,000 KRW)
# - 주요 숙소: Ibis Ambassador Seoul Myeongdong (150,000 KRW, Classic Room 2인)
# - 교통: AREX 9,000 KRW → KTX (Seoul ↔ Incheon) 25,000 KRW (왕복) + 지하철 1일권 6,000 KRW ×2일 = 34,000 KRW
# - 식사: 총 171,000 KRW (점심·저녁 3회)
# - 입장료·체험: 총 155,000 KRW (Seoul City Pass 활용 시 25,000 KRW)
# - 기타·기념품·팁: 30,000 KRW
# - 예비비: 2,000 KRW
# - **총합**: 498,000 KRW (예산 내)
# ```
#
# ### 상세 일정표
# | Day | Time | Activity | Location | 비고 |
# |-----|------|----------|----------|------|
# | 1 | 10:00 | 도착 (인천→서울) | Gimpo → AREX → Seoul Station | |
# | 1 | 12:30 | 점심 | Myeongdong Kalguksu | 30 000 KRW |
# | 1 | 14:00~16:00 | 경복궁·북촌 한옥마을 | Jongno | 입장료 15 000 KRW |
# | 1 | 18:30 | 저녁 | Mokryeonjeong | 40 000 KRW |
# | 2 | 09:30~12:00 | N서울타워·동대문·DDP | Namsan·Dongdaemun | 입장료 20 000 KRW |
# | 2 | 13:30~17:30 | 롯데월드 | Lotte World | 할인 쿠폰 30 000 KRW |
# | 2 | 19:00 | 저녁 (한강 BBQ) | Hangang Park | 48 000 KRW |
# | 3 | 09:30~11:00 | COEX Aquarium | COEX | 50 000 KRW (City Pass 사용) |
# | 3 | 12:00 | 점심 | 김밥천국 | 21 000 KRW |
# | 3 | 13:30~15:00 | 쇼핑·여유시간 | COEX 몰 | |
# | 3 | 15:00 | 출국 (서울→인천) | KTX | 25 000 KRW |
#
# ### 교통·숙소 상세
# - **교통 패스**: T‑money 카드 (5,000 KRW 초기 충전) + 1일권 (2일) → 18,000 KRW
# - **숙소 예약**: Ibis Ambassador Myeongdong – “Classic Room, 2인, 2박” → 150,000 KRW (조기 예약 시 135,000 KRW)
# - **예약 방법**: 위 URL 접속 → 날짜 선택 → 할인코드 적용 → 결제
#
# ---
#
# ## 8️⃣ 결론 & 사용자 전달
#
# - **예산**: 전체 498 000 KRW (500 000 KRW 이하) → **예산 초과 없음**
# - **핵심 포인트**:
#   1. **교통**은 AREX + KTX 조합으로 가장 빠르게 이동, 비용은 34 000 KRW.
#   2. **숙소**는 명동에 위치한 Ibis Ambassador Myeongdong을 조기 예약·할인코드 적용해 135 000 KRW(2박)로 절감.
#   3. **입장료**는 Seoul City Pass(48 h)로 25 000 KRW에 주요 관광지(경복궁·N타워·COEX Aquarium 등) 모두 이용.
#   4. **식사**는 맛집·시장·BBQ를 적절히 배분, 평균 비용을 7 ~ 12 만원 수준으로 유지.
#   5. **예비비**와 **비상 상황**을 위한 2 000 KRW를 남겨 두어 안심하고 여행 가능.
#
# > **사용자에게 제공한 최종 문서**는 위 “최종 여행 계획 문서”와 “상세 일정표”를 PDF·한글 파일로 다운로드하거나, 메신저(카카오톡·라인)로 바로 공유할 수 있습니다. 필요 시 **예약 링크**와 **할인 코드**를 별도로 안내드립니다.
#
# ---
#
# **※** 모든 금액은 2026‑01 시점 기준 평균 가격이며, 실제 예약·구매 시 변동 가능하니 **사전 확인**을 권장합니다.

# %% [markdown]
# ### Test: Reflection 패턴 실행 결과 확인
#
# **확인 기준**:
# - [ ] Reflection Agent가 Worker의 결과를 검토했는가?
# - [ ] 충족 여부 판정이 이루어졌는가?
# - [ ] 개선이 필요한 경우 Worker가 재실행되었는가?
# - [ ] 최종 결과에 개선 내용이 반영되었는가?
#
# **체감 포인트**: "Reflection Agent가 자동으로 결과를 검토하고 품질을 높여주니, 수동 검토 없이도 신뢰할 수 있는 결과를 얻을 수 있구나!"

# %% [markdown]
# ---
# ## 트러블슈팅 가이드
#
# 실습/과제 진행 중 자주 발생하는 오류와 해결 방법입니다.
#
# ### API 관련
#
# | 증상 | 원인 | 해결 방법 |
# |------|------|----------|
# | `AuthenticationError` | API Key 미설정 또는 잘못된 키 | `.env` 파일에 `OPENAI_API_KEY` 확인 |
# | `RateLimitError` | API 호출 한도 초과 | 잠시 대기 후 재실행 (1~2분) |
# | `InvalidRequestError` | 토큰 제한 초과 | 입력 텍스트 길이 줄이기 또는 청킹 크기 조정 |
#
# ### 패키지 관련
#
# | 증상 | 원인 | 해결 방법 |
# |------|------|----------|
# | `ModuleNotFoundError` | 패키지 미설치 | Step 1의 `%pip install` 셀 재실행 |
# | `ImportError: cannot import name` | 버전 불일치 | `%pip install --upgrade <패키지>` |
# | ChromaDB `sqlite3` 오류 | SQLite 버전 낮음 | `%pip install pysqlite3-binary` 후 커널 재시작 |
#
# ### 일반
#
# | 증상 | 원인 | 해결 방법 |
# |------|------|----------|
# | `NameError: name 'xxx' is not defined` | 이전 셀 미실행 | Step 1부터 순서대로 재실행 |
# | 출력이 비어있음 | 환경 변수 로드 실패 | `.env` 파일 경로 확인 후 커널 재시작 |

# %% [markdown]
# ---
#
# ## 실습 마무리
#
# ### 학습 내용 정리
#
# 이번 실습에서 배운 핵심 내용:
#
# 1. **단일 Agent의 한계**: 복잡한 작업에서 혼란, 누락, 품질 저하 발생
# 2. **Multi-Agent 대표 패턴**: Planner-Worker, Supervisor, Debate, Reflection, Hierarchical
# 3. **Planner-Worker 패턴**: 계획 수립과 실행을 분리하여 체계적 결과 도출
# 4. **Reflection 패턴**: 자기 검토 루프로 결과 품질 향상
# 5. **LangGraph StateGraph**: 상태 기반 워크플로우로 에이전트 간 협업 구현
#
# ### 학생용 자가 체크리스트
#
# - [ ] 단일 Agent의 한계를 직접 체험했는가?
# - [ ] Multi-Agent 대표 패턴 5가지를 설명할 수 있는가?
# - [ ] LangGraph State를 정의하고 이해했는가?
# - [ ] Planner Node가 계획을 수립하는 코드를 작성했는가?
# - [ ] Worker Node가 계획을 실행하는 코드를 작성했는가?
# - [ ] Reflection Node가 결과를 검토하고 개선하는 코드를 작성했는가?
# - [ ] Reflection 패턴 전후 결과 품질 차이를 확인했는가?
# - [ ] 성과 평가 함수로 결과 품질을 정량적으로 측정했는가?

# %% [markdown]
# ---
#
# ### **Content License Agreement**
#
# <font color='red'><b>**WARNING**</b></font> : 본 자료는 삼성 청년 SW아카데미의 컨텐츠 자산으로, 보안서약서에 의거하여 어떠한 사유로도 임의로 복사, 촬영, 녹음, 복제, 보관, 전송하거나 허가 받지 않은 저장매체를 이용한 보관, 제3자에게 누설, 공개 또는 사용하는 등의 무단 사용 및 불법 배포 시 법적 조치를 받을 수 있습니다.
